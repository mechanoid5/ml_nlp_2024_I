# %% [markdown]
# **Статистическая языковая модель**
#
# Евгений Борисов <esborisov@sevsu.ru>
#
# подбираем наиболее вероятное продолжение цепочки слов

# %%
import gzip
import requests
from bs4 import BeautifulSoup

# %%
url='http://lib.ru/NEWPROZA/LOBAS/taxisty.txt'
text = BeautifulSoup(requests.get(url).text).get_text()
with gzip.open('taxisty.txt.gz','wt') as f: f.write(text)

# with gzip.open('taxisty.txt.gz','rt') as f: text = f.read()

text = text[1030:-7261].strip() # выкидываем заголовок и хвост страницы 
print(f'символов:{len(text)}\n---------------\n'%())
print(text[:343])
# Out:
# символов:637930
# ---------------
#
# .
#      Вы прилетели в  Нью-Йорк и  остановились  в  одном  из отелей, глядящих
# окнами на Центральный парк.  Наутро по  приезде вы вышли из  отеля, вдохнули
# полной грудью очищенный зеленью парка воздух  и,  взглянув на часы, --  пора
# было начинать хлопотливый день, --  направились к  первому из  таксомоторов,
# выстроившихся вереницей у подъез

# %%
# url='http://az.lib.ru/d/dostoewskij_f_m/text_0080.shtml'
# text = BeautifulSoup(requests.get(url).text).get_text()
# with gzip.open('dostoewskij.txt.gz','wt') as f: f.write(text)

# # with gzip.open('dostoewskij.txt.gz','rt') as f: text = f.read()

# text = text[2876:-664184].strip() # выкидываем заголовок и хвост страницы 
# print(f'символов:{len(text)}\n---------------\n'%())
# print(text[:355])

# %%
from nltk import __version__ as nltk_version
print('nltk version:',nltk_version)
# Out:
# nltk version: 3.8.1

# %%
from tqdm.auto import tqdm
from random import sample

from nltk.tokenize import sent_tokenize as nltk_sentence_split
from nltk.tokenize import word_tokenize as nltk_tokenize_word

sentences = [ 
    nltk_tokenize_word(s) # разбиваем предложения на слова
    for s in tqdm(nltk_sentence_split(text)) # режем текст на отдельные предложения
]

print('предложений: %i\n'%(len(sentences)))
display( sample(sentences,1) )
# Out:
#   0%|          | 0/6687 [00:00<?, ?it/s]
# предложений: 6687
# [['Выслушав',
#   'мои',
#   'ответы',
#   ',',
#   'незнакомка',
#   'сказала',
#   ',',
#   'что',
#   ',',
#   'по-видимому',
#   ',',
#   'мы',
#   'подойдем',
#   'друг',
#   'другу',
#   'и',
#   'предложила',
#   'встретиться',
#   'на',
#   'Брайтоне',
#   'у',
#   'входа',
#   'в',
#   'кафе',
#   '``',
#   'Мечта',
#   "''",
#   '.']]

# %%
# sentences = sentences[:1024] # ограничиваем датасет для ускорения процеса

# %% [markdown]
# ---

# %%
from itertools import chain
from collections import Counter

text_tokens = list(chain(*sentences)) # собираем все токены (слова) из текста
vocab_size = len(set(text_tokens)) # размер словаря

text_tokens_freq = Counter( text_tokens ) # оценка частоты использования слов

print('всего слов тексте: %i'%(len(text_tokens)))
print('размер словаря: %i'%(vocab_size))
text_tokens_freq.most_common()[:10] # наиболее частые токены
# Out:
# всего слов тексте: 117133
# размер словаря: 24063
# [(',', 10727),
#  ('--', 4221),
#  ('.', 4034),
#  ('и', 2453),
#  ('в', 2409),
#  ('не', 2077),
#  ('я', 1513),
#  ('!', 1470),
#  ("''", 1411),
#  ('...', 1392)]

# %% [markdown]
# ----

# %%
# from nltk.util import bigrams
from nltk.util import ngrams as nltk_ngrams

# вынимаем все n-gram из текста
ngram_len = 2 # работаем с биграммами
text_ngrams = [ ngram for s in sentences for ngram in nltk_ngrams(s,ngram_len) ]
print('количество n-gram: %i'%(len(set(text_ngrams))))
sample(text_ngrams,5)
# Out:
# количество n-gram: 72665
# [('не', 'выбраться'),
#  ('А', 'вот'),
#  ('ли', 'не'),
#  ('в', 'аэропорт'),
#  ('чекер', '.')]

# %%
# cчитаем частоту n-gram
text_ngrams_freq = Counter(text_ngrams)
sample( list(text_ngrams_freq.items()), 7)
# Out:
# [(('машине', 'мне'), 1),
#  (('и', 'чтением'), 1),
#  (('приносит', ','), 1),
#  (('метров', ','), 1),
#  (('давно', 'готовился'), 1),
#  (('стоит', 'человек'), 1),
#  (('поддакнул', ','), 1)]

# %%
text_ngrams_freq.most_common()[:10] # наиболее частые n-ngram
# Out:
# [((',', 'что'), 807),
#  ((',', 'и'), 631),
#  ((',', 'а'), 466),
#  ((',', '--'), 420),
#  ((',', 'как'), 384),
#  ((':', '--'), 366),
#  ((',', 'но'), 319),
#  ((',', 'я'), 297),
#  (("''", ','), 294),
#  ((',', 'не'), 247)]

# %% [markdown]
# ----

# %% [markdown]
# Оценка вероятностей совместного использования слов со сглаживанием Лапласа
#
#
# $$
# P(w_n|w_{n-1}) = \frac{ C(w_{n-1} w_{n}) +1 }{ C(w_{n-1}) + V }
# $$

# %%
text_ngrams_prob = { # оценка совместного использования токенов
    ngram : (text_ngrams_freq[ngram]+1) / ( text_tokens_freq[ ngram[0] ] + vocab_size )
    for ngram in text_ngrams_freq 
}

display( text_ngrams_prob )
# Out:
# {('Вы', 'прилетели'): 0.0001244090569793481,
#  ('прилетели', 'в'): 0.0001246623727404945,
#  ('в', 'Нью-Йорк'): 0.0003399818676337262,
#  ('Нью-Йорк', 'и'): 0.0001660371092939272,
#  ('и', 'остановились'): 7.54261577915221e-05,
#  ('остановились', 'в'): 8.309788931361143e-05,
#  ('в', 'одном'): 0.0003022061045633122,
#  ('одном', 'из'): 0.00029074597109154346,
#  ('из', 'отелей'): 0.0001221697344844437,
#  ('отелей', ','): 0.00012464683397041715,
#  (',', 'глядящих'): 5.748778384593274e-05,
#  ('глядящих', 'окнами'): 8.311170212765957e-05,
#  ('окнами', 'на'): 8.31013420866747e-05,
#  ('на', 'Центральный'): 0.00011793379982703042,
#  ('Центральный', 'парк'): 0.00024927295388450354,
#  ('парк', '.'): 0.00012464683397041715,
#  ('Наутро', 'по'): 8.310479514667997e-05,
#  ('по', 'приезде'): 0.00024467824810374357,
#  ('приезде', 'вы'): 8.309788931361143e-05,
#  ('вы', 'вышли'): 8.246062505153789e-05,
#  ('вышли', 'из'): 0.00016619577862722287,
#  ('из', 'отеля'): 0.00040723244828147904,
#  ('отеля', ','): 0.0003318813524165111,
#  (',', 'вдохнули'): 5.748778384593274e-05,
#  ('вдохнули', 'полной'): 8.311170212765957e-05,
#  ('полной', 'грудью'): 0.00012465719272001995,
#  ('грудью', 'очищенный'): 8.3108248493663e-05,
#  ('очищенный', 'зеленью'): 8.311170212765957e-05,
#  ('зеленью', 'парка'): 8.311170212765957e-05,
#  ('парка', 'воздух'): 8.30944368274544e-05,
#  ('воздух', 'и'): 8.309788931361143e-05,
#  ('и', ','): 0.004035299441846433,
#  (',', 'взглянув'): 0.00011497556769186548,
#  ('взглянув', 'на'): 0.00020775335521668674,
#  ('на', 'часы'): 0.000275178866263071,
#  ('часы', ','): 0.0003736610479116499,
#  (',', '--'): 0.012101178499568842,
#  ('--', 'пора'): 0.0001414227124876255,
#  ('пора', 'было'): 8.309098462816784e-05,
#  ('было', 'начинать'): 8.208495793145906e-05,
#  ('начинать', 'хлопотливый'): 8.310479514667997e-05,
#  ('хлопотливый', 'день'): 8.311170212765957e-05,
#  ('день', ','): 0.0007034094670638862,
#  ('--', 'направились'): 7.071135624381275e-05,
#  ('направились', 'к'): 0.00020774472328402858,
#  ('к', 'первому'): 8.181632235631008e-05,
#  ('первому', 'из'): 8.310479514667997e-05,
#  ('из', 'таксомоторов'): 8.144648965629581e-05,
#  ('таксомоторов', ','): 8.3108248493663e-05,
#  (',', 'выстроившихся'): 5.748778384593274e-05,
#  ('выстроившихся', 'вереницей'): 8.3108248493663e-05,
#  ('вереницей', 'у'): 8.311170212765957e-05,
#  ('у', 'подъезда'): 0.0004898159108535043,
#  ('подъезда', '.'): 0.00016605089459919466,
#  ('Несколько', 'странным'): 8.31013420866747e-05,
#  ('странным', 'вам'): 8.3108248493663e-05,
#  ('вам', 'показалось'): 8.285347363188202e-05,
#  ('показалось', ','): 0.0002492936679408343,
#  (',', 'что'): 0.023225064673756828,
#  ('что', 'водители'): 7.983394539358135e-05,
#  ('водители', 'двух'): 8.305647840531562e-05,
#  ('двух', 'головных'): 8.30357884248111e-05,
#  ('головных', 'машин'): 8.311170212765957e-05,
#  ('машин', 'таксистской'): 8.300821781356355e-05,
#  ('таксистской', 'очереди'): 0.00016616125950234703,
#  ('очереди', 'находились'): 8.300821781356355e-05,
#  ('находились', 'не'): 8.309098462816784e-05,
#  ('не', 'там'): 0.00011476664116296863,
#  ('там', ','): 0.0010766045548654243,
#  (',', 'где'): 0.002701925840758839,
#  ('где', 'им'): 8.274036074797286e-05,
#  ('им', 'полагалось'): 8.291873963515754e-05,
#  ('полагалось', 'бы'): 0.0001246416552411816,
#  ('бы', ':'): 0.00020538098172109262,
#  (':', 'за'): 0.0004724595456514036,
#  ('за', 'баранкой'): 0.00028480755146879325,
#  ('баранкой', ','): 0.0001246416552411816,
#  (',', 'а'): 0.013423397528025295,
#  ('а', ','): 0.00044775511865510645,
#  (',', 'подпирая'): 5.748778384593274e-05,
#  ('подпирая', 'спинами'): 8.3108248493663e-05,
#  ('спинами', 'стену'): 8.311170212765957e-05,
#  ('стену', 'отеля'): 8.31013420866747e-05,
#  (',', 'о'): 0.001092267893072722,
#  ('о', 'чем-то'): 0.0004114887663566785,
#  ('чем-то', 'болтали'): 8.306337735692334e-05,
#  ('болтали', ','): 8.31013420866747e-05,
#  (',', 'на'): 0.0028456453003736708,
#  ('на', 'пассажира'): 0.00011793379982703042,
#  ('пассажира', ','): 0.0004562233005682054,
#  (',', 'заглядывавшего'): 5.748778384593274e-05,
#  ('заглядывавшего', 'в'): 8.311170212765957e-05,
#  ('в', 'окна'): 7.555152614082804e-05,
#  ('окна', 'кэбов'): 8.308408109006314e-05,
#  ('кэбов', ','): 0.00024912805181863477,
#  (',', 'внимания'): 5.748778384593274e-05,
#  ('внимания', 'не'): 8.305647840531562e-05,
#  ('не', 'обращали'): 7.651109410864575e-05,
#  ('обращали', ','): 8.311170212765957e-05,
#  (',', 'и'): 0.018166139695314745,
#  ('и', 'выглядело'): 7.54261577915221e-05,
#  ('выглядело', 'это'): 8.310479514667997e-05,
#  ('это', 'так'): 0.0002868264699856587,
#  ('так', ','): 0.001151742009789807,
#  (',', 'будто'): 0.00045990227076746193,
#  ('будто', 'они'): 0.00012456402590931738,
#  ('они', 'оба'): 0.00012395669779357077,
#  ('оба', 'вообще'): 8.306337735692334e-05,
#  ('вообще', 'никуда'): 8.300132802124833e-05,
#  ('никуда', 'не'): 0.00016620959029335994,
#  ('не', 'собирались'): 0.00011476664116296863,
#  ('собирались', 'ехать'): 8.31013420866747e-05,
#  ('ехать', '.'): 0.0001245278319704454,
#  ('Выждав', 'минуту'): 8.311170212765957e-05,
#  ('минуту', 'и'): 8.305992773786287e-05,
#  ('и', 'поняв'): 7.54261577915221e-05,
#  ('поняв', ','): 0.00016620959029335994,
#  ('что', 'беседа'): 7.983394539358135e-05,
#  ('беседа', 'таксистов'): 8.311170212765957e-05,
#  ('таксистов', 'может'): 8.29324929507381e-05,
#  ('может', 'длиться'): 8.281916435463166e-05,
#  ('длиться', 'бесконечно'): 8.311170212765957e-05,
#  ('бесконечно', ','): 8.311170212765957e-05,
#  (',', 'вы'): 0.0008048289738430583,
#  ('вы', 'решились'): 8.246062505153789e-05,
#  ('решились', ','): 8.3108248493663e-05,
#  (',', 'наконец'): 0.0005173900546133947,
#  ('наконец', ','): 0.0007887744935237463,
#  (',', 'прервать'): 5.748778384593274e-05,
#  ('прервать', 'этот'): 8.311170212765957e-05,
#  ('этот', 'милый'): 8.271640679928864e-05,
#  ('милый', 'tet-a-tet'): 8.3108248493663e-05,
#  ('tet-a-tet', 'и'): 8.311170212765957e-05,
#  ('и', 'спросили'): 7.54261577915221e-05,
#  ('спросили', ':'): 8.3108248493663e-05,
#  (':', '--'): 0.014449387771172094,
#  ('--', 'Ну'): 0.0008838919530476595,
#  ('Ну', ','): 0.0026919572600016565,
#  (',', 'ребята'): 0.00011497556769186548,
#  ('ребята', ','): 0.00012465201313001205,
#  (',', 'кто'): 0.0013797068123023858,
#  ('кто', 'из'): 0.00020716801325875285,
#  ('из', 'вас'): 0.0001221697344844437,
#  ('вас', 'отвезет'): 8.282259400364419e-05,
#  ('отвезет', 'меня'): 8.311170212765957e-05,
#  ('меня', '?'): 0.0002849930787395163,
#  ('--', 'Мой'): 0.0001414227124876255,
#  ('Мой', 'кэб'): 0.0001245898916067943,
#  ('кэб', 'занят'): 8.251846350620951e-05,
#  ('занят', ','): 0.0001246416552411816,
#  ('--', 'чуть'): 7.071135624381275e-05,
#  ('чуть', 'поморщившись'): 8.299443937256204e-05,
#  ('поморщившись', ','): 0.0001246623727404945,
#  (',', 'отвечал'): 0.00014371945961483184,
#  ('отвечал', 'один'): 8.302889405513119e-05,
#  ('один', 'из'): 0.0011996855996359575,
#  ('из', 'водителей'): 0.0001221697344844437,
#  ('водителей', '.'): 0.0001661405549094534,
#  ('--', 'Разве'): 0.000282845424975251,
#  ('Разве', 'вы'): 0.0001660164356271271,
#  ('вы', 'не'): 0.0003710728127319205,
#  ('не', 'видите'): 7.651109410864575e-05,
#  ('видите', ','): 0.00012465201313001205,
#  ('что', 'мы'): 0.00039916972696790677,
#  ('мы', 'разговариваем'): 8.247762794342034e-05,
#  ('разговариваем', '?'): 8.311170212765957e-05,
#  ('--', 'с'): 0.0016617168717295997,
#  ('с', 'режущим'): 8.027292795504716e-05,
#  ('режущим', 'слух'): 8.311170212765957e-05,
#  ('слух', 'акцентом'): 8.31013420866747e-05,
#  ('акцентом', 'сказал'): 8.310479514667997e-05,
#  ('сказал', 'второй'): 8.25559316436886e-05,
#  ('второй', 'и'): 0.0001244606704281447,
#  ('и', 'при'): 0.00026399155227032733,
#  ('при', 'этом'): 0.00033168871014552844,
#  ('этом', 'покачал'): 8.297378028542981e-05,
#  ('покачал', 'головой'): 0.0002908305288960904,
#  ('головой', ','): 0.00020764119601328904,
#  (',', 'сетуя'): 5.748778384593274e-05,
#  ('сетуя', 'на'): 8.311170212765957e-05,
#  ('на', 'всеобщую'): 7.862253321802028e-05,
#  ('всеобщую', 'невоспитанность'): 8.311170212765957e-05,
#  ('невоспитанность', '.'): 8.311170212765957e-05,
#  ('Чтобы', 'избежать'): 8.307717869901138e-05,
#  ('избежать', 'препирательств'): 8.3108248493663e-05,
#  ('препирательств', ','): 8.311170212765957e-05,
#  ('вы', 'шагнули'): 8.246062505153789e-05,
#  ('шагнули', 'было'): 8.311170212765957e-05,
#  ('было', 'к'): 8.208495793145906e-05,
#  ('к', 'третьей'): 0.00012272448353446513,
#  ('третьей', 'машине'): 0.00012463647694225177,
#  ('машине', ','): 0.00037344398340248964,
#  (',', 'но'): 0.009198045415349238,
#  ('но', 'водитель'): 8.191685439279132e-05,
#  ('водитель', ','): 0.00024908668216539354,
#  (',', 'находившийся'): 5.748778384593274e-05,
#  ('находившийся', 'именно'): 8.311170212765957e-05,
#  ('именно', 'там'): 8.295657223443528e-05,
#  ('где', 'ему'): 8.274036074797286e-05,
#  ('ему', 'и'): 0.00016530974914245568,
#  ('и', 'положено'): 0.00011313923668728315,
#  ('положено', ','): 8.308408109006314e-05,
#  (',', 'защелкнул'): 5.748778384593274e-05,
#  ('защелкнул', 'автоматический'): 8.311170212765957e-05,
#  ('автоматический', 'замок'): 0.00016620959029335994,
#  ('замок', '...'): 8.30944368274544e-05,
#  ('...', 'Несуразный'): 7.85700255352583e-05,
#  ('Несуразный', 'бойкот'): 8.311170212765957e-05,
#  ('бойкот', 'этот'): 8.311170212765957e-05,
#  ('этот', 'был'): 8.271640679928864e-05,
#  ('был', 'тем'): 8.243683277688472e-05,
#  ('тем', 'более'): 0.00020709078860172298,
#  ('более', 'оскорбителен'): 8.302544729959733e-05,
#  ('оскорбителен', ','): 8.3108248493663e-05,
#  ('что', 'невозможно'): 7.983394539358135e-05,
#  ('невозможно', 'было'): 0.0001661405549094534,
#  ('было', 'понять'): 8.208495793145906e-05,
#  ('понять', ','): 0.0004569244828445626,
#  (',', 'чем'): 0.0019833285426846797,
#  ('чем', ','): 0.00012393621416177807,
#  (',', 'собственно'): 0.00034492670307559645,
#  ('собственно', ','): 0.0004984630721940683,
#  (',', 'он'): 0.002127048002299511,
#  ('он', 'вызван'): 8.164598301763554e-05,
#  ('вызван', '...'): 8.3108248493663e-05,
#  ('...', 'Остановив'): 7.85700255352583e-05,
#  ('Остановив', 'пробегавшее'): 8.311170212765957e-05,
#  ('пробегавшее', 'мимо'): 8.311170212765957e-05,
#  ('мимо', 'такси'): 0.00016593379241682568,
#  ('такси', ','): 0.0014049006239411595,
#  ('вы', 'постарались'): 8.246062505153789e-05,
#  ('постарались', 'как'): 0.0001246623727404945,
#  ('как', 'можно'): 0.00020368258106566727,
#  ('можно', 'скорее'): 0.0001244296972210701,
#  ('скорее', 'забыть'): 0.00012465201313001205,
#  ('забыть', 'о'): 0.00020771883178929003,
#  ('о', 'случившемся'): 0.00016459550654267138,
#  ('случившемся', '.'): 8.310479514667997e-05,
#  ('Но', 'несколько'): 8.203781943475943e-05,
#  ('несколько', 'часов'): 0.00024897298643097225,
#  ('часов', 'спустя'): 8.298755186721991e-05,
#  ('спустя', ','): 0.00020770157437793377,
#  (',', 'перед'): 0.00014371945961483184,
#  ('перед', 'вечером'): 8.290842764166977e-05,
#  ('вечером', ','): 8.310479514667997e-05,
#  (',', 'когда'): 0.0043403276803679215,
#  ('когда', 'переодевшись'): 8.243683277688472e-05,
#  ('переодевшись', ','): 8.311170212765957e-05,
#  (',', 'об'): 8.623167576889911e-05,
#  ('об', 'руку'): 0.0001245226631246887,
#  ('руку', 'с'): 0.00012446583412853172,
#  ('с', 'благоухающей'): 8.027292795504716e-05,
#  ('благоухающей', 'женой'): 8.311170212765957e-05,
#  ('женой', 'вы'): 8.30702774547267e-05,
#  ('вы', 'снова'): 8.246062505153789e-05,
#  ('снова', 'вышли'): 8.300821781356355e-05,
#  (',', 'безобразная'): 5.748778384593274e-05,
#  ('безобразная', 'сцена'): 8.311170212765957e-05,
#  ('сцена', 'повторилась'): 8.3108248493663e-05,
#  ('повторилась', '.'): 8.311170212765957e-05,
#  ('Было', 'время'): 8.307717869901138e-05,
#  ('время', '``'): 8.288781134734137e-05,
#  ('``', 'пик'): 0.00031566902103144853,
#  ('пик', "''"): 0.00033236393851267135,
#  ("''", ','): 0.011580434953285703,
#  (',', 'в'): 0.005777522276516241,
#  ('в', 'потоке'): 0.00011332728921124207,
#  ('потоке', 'машин'): 8.3108248493663e-05,
#  ('машин', 'свободное'): 8.300821781356355e-05,
#  ('свободное', 'такси'): 8.3108248493663e-05,
#  ('такси', 'все'): 0.00012396181975951408,
#  ('все', 'никак'): 0.00024631553019417875,
#  ('никак', 'не'): 0.0007889054974256768,
#  ('не', 'попадалось'): 0.00011476664116296863,
#  ('попадалось', ','): 0.0001246623727404945,
#  ('а', 'у'): 0.00024423006472096715,
#  ('подъезда', 'стоял'): 8.302544729959733e-05,
#  ('стоял', 'лишь'): 8.301510874979246e-05,
#  ('лишь', 'один-единственный'): 8.288781134734137e-05,
#  ('один-единственный', 'желтый'): 8.311170212765957e-05,
#  ('желтый', 'кэб'): 0.0005812263876780006,
#  ('кэб', '.'): 0.0004951107810372571,
#  ('Неопрятный', 'субъект'): 8.311170212765957e-05,
#  ('субъект', 'с'): 8.311170212765957e-05,
#  ('с', 'помутневшим'): 8.027292795504716e-05,
#  ('помутневшим', 'то'): 8.311170212765957e-05,
#  ('то', 'ли'): 0.0006597666075625748,
#  ('ли', 'от'): 0.0002477700693756194,
#  ('от', 'пива'): 0.0001234669520125113,
#  ('пива', ','): 0.00016619577862722287,
#  (',', 'то'): 0.002328255245760276,
#  ('от', 'безделья'): 8.231130134167421e-05,
#  ('безделья', 'взглядом'): 8.311170212765957e-05,
#  ('взглядом', 'сидел'): 8.306337735692334e-05,
#  ('сидел', 'на'): 0.00016618196925633567,
#  ('на', 'капоте'): 0.00031449013287208113,
#  ('капоте', 'и'): 0.00012462094462676026,
#  ('и', 'болтал'): 7.54261577915221e-05,
#  ('болтал', 'ногами'): 8.3108248493663e-05,
#  ('ногами', '.'): 8.309098462816784e-05,
#  ('--', 'Дружище'): 7.071135624381275e-05,
#  ('Дружище', ','): 8.311170212765957e-05,
#  (',', 'сделайте'): 5.748778384593274e-05,
#  ('сделайте', 'одолжение'): 8.311170212765957e-05,
#  ('одолжение', ','): 8.3108248493663e-05,
#  ('--', 'едва'): 7.071135624381275e-05,
#  ('едва', 'ли'): 0.00024897298643097225,
#  ('ли', 'не'): 0.0007846052196894615,
#  ('не', 'заискивая'): 7.651109410864575e-05,
#  ('заискивая', ','): 8.311170212765957e-05,
#  (',', 'обратились'): 5.748778384593274e-05,
#  ('обратились', 'вы'): 8.311170212765957e-05,
#  ('вы', 'к'): 8.246062505153789e-05,
#  ('к', 'нему'): 0.0007363469012067908,
#  ('нему', ':'): 8.305647840531562e-05,
#  ('--', 'отвезите'): 7.071135624381275e-05,
#  ('отвезите', 'нас'): 8.31013420866747e-05,
#  ('нас', 'в'): 0.00024878716258241074,
#  ('в', 'ресторан'): 7.555152614082804e-05,
#  ('ресторан', '.'): 8.310479514667997e-05,
#  ('Это', 'совсем'): 8.27780307106494e-05,
#  ('совсем', 'недалеко'): 8.285347363188202e-05,
#  ('недалеко', ','): 8.311170212765957e-05,
#  ('а', 'мы'): 0.0002035250539341393,
#  ('мы', 'будем'): 0.00016495525588684068,
#  ('будем', 'вам'): 0.0001246416552411816,
#  ('вам', 'очень'): 8.285347363188202e-05,
#  ('очень', 'признательны'): 8.297722275235447e-05,
#  ('признательны', '.'): 8.3108248493663e-05,
#  ('Туповатый', 'таксист'): 8.311170212765957e-05,
#  ('таксист', ','): 0.0004975743251648215,
#  (',', 'однако'): 0.0010635240011497556,
#  ('однако', ','): 0.0014518002322880372,
#  (',', 'не'): 0.00712848519689566,
#  ('не', 'понял'): 0.00019127773527161438,
#  ('понял', 'намека'): 8.299443937256204e-05,
#  ('намека', '.'): 8.311170212765957e-05,
#  ('Он', 'с'): 0.00012385946079848065,
#  ('с', 'натугой'): 0.00012040939193257074,
#  ('натугой', 'подавил'): 8.3108248493663e-05,
#  ('подавил', 'зевок'): 8.3108248493663e-05,
#  ('зевок', 'и'): 8.3108248493663e-05,
#  (',', 'проморгавшись'): 5.748778384593274e-05,
#  ('проморгавшись', ','): 8.311170212765957e-05,
#  (',', 'сказал'): 0.00020120724346076458,
#  ('сказал', ':'): 0.001114505077189796,
#  ('--', 'Я'): 0.003005232640362042,
#  ('Я', 'никуда'): 0.0001224739742804654,
#  ('не', 'поеду'): 0.00026778882938026014,
#  ('поеду', '.'): 0.00012462094462676026,
#  ('Я', '--'): 0.00020412329046744235,
#  ('--', 'отдыхаю'): 7.071135624381275e-05,
#  ('отдыхаю', '.'): 8.3108248493663e-05,
#  ('Швейцар', 'отвернулся'): 8.307372793354102e-05,
#  ('отвернулся', ';'): 8.3108248493663e-05,
#  (';', 'ему'): 0.00012311227839789887,
#  ('ему', ','): 0.0005785841219985949,
#  (',', 'наверное'): 0.0009485484334578901,
#  ('наверное', ','): 0.0014110225763612218,
#  (',', 'было'): 0.00045990227076746193,
#  ('было', 'стыдно'): 8.208495793145906e-05,
#  ('стыдно', 'наблюдать'): 8.308408109006314e-05,
#  ('наблюдать', 'эдакое'): 8.3108248493663e-05,
#  ('эдакое', 'измывательство'): 8.311170212765957e-05,
#  ('измывательство', 'над'): 8.311170212765957e-05,
#  ('над', 'гостями'): 8.294625082946251e-05,
#  ('гостями', 'престижного'): 8.311170212765957e-05,
#  ('престижного', 'отеля-'): 8.311170212765957e-05,
#  ('отеля-', 'Пришлось'): 8.311170212765957e-05,
#  ('Пришлось', 'повысить'): 8.31013420866747e-05,
#  ('повысить', 'голос'): 8.311170212765957e-05,
#  ('голос', ','): 0.0001661405549094534,
#  (',', 'окликнуть'): 5.748778384593274e-05,
#  ('окликнуть', 'швейцара'): 8.311170212765957e-05,
#  ('швейцара', ','): 0.00037359900373599005,
#  ('и', 'тот'): 0.0001508523155830442,
#  ('тот', ','): 0.00045614762595894674,
#  (',', 'надо'): 0.0003736705949985628,
#  ('надо', 'сказать'): 0.00024874590605696283,
#  ('сказать', ','): 0.0008294281093186248,
#  (',', 'живо'): 8.623167576889911e-05,
#  ('живо', 'навел'): 8.310479514667997e-05,
#  ('навел', 'порядок'): 8.311170212765957e-05,
#  ('порядок', ':'): 0.00012464683397041715,
#  (':', 'развязный'): 7.874325760856726e-05,
#  ('развязный', 'кэбби'): 8.311170212765957e-05,
#  ('кэбби', 'в'): 0.0002062621178994266,
#  ('в', 'два'): 0.0001888788153520701,
#  ('два', 'счета'): 0.0001242647667964543,
#  ('счета', 'оказался'): 8.3108248493663e-05,
#  ('оказался', 'за'): 0.000124538170949396,
#  ('за', 'рулем'): 0.0004475547237366751,
#  ('рулем', '.'): 0.00012461576804851708,
#  ('Но', ','): 0.0007793592846302146,
#  (',', 'Бог'): 8.623167576889911e-05,
#  ('Бог', 'ты'): 0.000124631299073574,
#  ('ты', 'мой'): 0.00012270942408376963,
#  ('мой', ','): 0.0003714250340472948,
#  (',', 'до'): 0.0005748778384593274,
#  ('до', 'чего'): 0.0002890054085297882,
#  ('чего', 'же'): 0.0003319088910094179,
#  ('же', 'это'): 0.0002041649652919559,
#  ('это', 'неприятно'): 8.195041999590248e-05,
#  ('неприятно', ','): 8.311170212765957e-05,
#  ('когда', 'везет'): 0.00012365524916532706,
#  ('везет', 'вас'): 8.31013420866747e-05,
#  ('вас', 'обозленный'): 8.282259400364419e-05,
#  ('обозленный', 'шоферюга'): 8.311170212765957e-05,
#  ('шоферюга', ','): 8.3108248493663e-05,
#  (',', 'который'): 0.0034492670307559644,
#  ('который', 'все'): 0.00012396694214876033,
#  ('все', 'время'): 0.0002873681185598752,
#  ('время', 'бурчит'): 8.288781134734137e-05,
#  ('бурчит', 'что-то'): 8.311170212765957e-05,
#  ('что-то', 'себе'): 8.297722275235447e-05,
#  ('себе', 'под'): 0.00016563832870926333,
#  ('под', 'нос'): 0.00016526876833450397,
#  ('нос', ','): 0.00012465719272001995,
#  (',', 'гримасничает'): 5.748778384593274e-05,
#  ('гримасничает', 'и'): 8.311170212765957e-05,
#  ('и', 'вам'): 0.00011313923668728315,
#  ('вам', 'назло'): 8.285347363188202e-05,
#  ('назло', 'резко'): 8.31013420866747e-05,
#  ('резко', 'тормозит'): 8.31013420866747e-05,
#  ('тормозит', 'на'): 8.311170212765957e-05,
#  ('на', 'перекрестках'): 0.00011793379982703042,
#  ('перекрестках', '.'): 8.3108248493663e-05,
#  ('Притихнув', 'на'): 8.311170212765957e-05,
#  ('на', 'заднем'): 0.00043242393269911155,
#  ('заднем', 'сиденье'): 0.0004153858934950569,
#  ('сиденье', ','): 0.0007468879668049793,
#  ('вы', 'молча'): 8.246062505153789e-05,
#  ('молча', 'разглядываете'): 8.309098462816784e-05,
#  ('разглядываете', 'плешивый'): 8.311170212765957e-05,
#  ('плешивый', 'затылок'): 8.3108248493663e-05,
#  ('затылок', 'над'): 8.30944368274544e-05,
#  ('над', 'несвежим'): 8.294625082946251e-05,
#  ('несвежим', 'воротничком'): 8.311170212765957e-05,
#  ('воротничком', 'и'): 8.311170212765957e-05,
#  ('и', '--'): 0.0021496454970583796,
#  ('--', 'в'): 0.002969876962240136,
#  ('в', 'зеркало'): 0.00022665457842248413,
#  ('зеркало', 'заднего'): 0.000207736092068636,
#  ('заднего', 'обзора'): 0.0002492522432701894,
#  ('обзора', '--'): 0.00012464683397041715,
#  ('--', 'обрюзгшие'): 7.071135624381275e-05,
#  ('обрюзгшие', 'небритые'): 8.311170212765957e-05,
#  ('небритые', 'щеки'): 8.311170212765957e-05,
#  ('щеки', '.'): 8.3108248493663e-05,
#  ('К', 'счастью'): 0.00012449165905884305,
#  ('счастью', ','): 0.00016620959029335994,
#  (',', 'поездка'): 5.748778384593274e-05,
#  ('поездка', 'длится'): 8.308753271571601e-05,
#  ('длится', 'лишь'): 8.311170212765957e-05,
#  ('лишь', 'считанные'): 8.288781134734137e-05,
#  ('считанные', 'минуты'): 0.00012465201313001205,
#  ('минуты', ','): 0.0004152823920265781,
#  ('когда', 'кэб'): 0.00012365524916532706,
#  ('кэб', 'останавливается'): 8.251846350620951e-05,
#  ('останавливается', ','): 0.00012464683397041715,
#  (',', 'счетчик'): 0.00017246335153779823,
#  ('счетчик', 'показывает'): 8.298755186721991e-05,
#  ('показывает', '1.80'): 8.31013420866747e-05,
#  ('1.80', '.'): 8.311170212765957e-05,
#  ('Инцидент', 'исчерпан'): 8.311170212765957e-05,
#  ('исчерпан', ';'): 8.311170212765957e-05,
#  (';', 'водителю'): 8.207485226526592e-05,
#  ('водителю', 'протянуты'): 8.308408109006314e-05,
#  ('протянуты', 'две'): 8.311170212765957e-05,
#  ('две', 'долларовые'): 8.301166313867098e-05,
#  ('долларовые', 'бумажки'): 0.0001246623727404945,
#  ('бумажки', 'и'): 8.30944368274544e-05,
#  ('и', 'сказано'): 7.54261577915221e-05,
#  ('сказано', ','): 0.00012465201313001205,
#  ('что', 'сдачу'): 7.983394539358135e-05,
#  ('сдачу', 'он'): 8.308408109006314e-05,
#  ('он', 'может'): 8.164598301763554e-05,
#  ('может', 'оставить'): 8.281916435463166e-05,
#  ('оставить', 'себе'): 8.309788931361143e-05,
#  ('себе', '.'): 0.0002898670752412108,
#  ('--', 'Зачем'): 0.00035355678121906376,
#  ('Зачем', 'ты'): 0.00012454334108269677,
#  ('ты', 'это'): 0.0001636125654450262,
#  ('это', 'делаешь'): 0.0001229256299938537,
#  ('делаешь', '?'): 0.00020775335521668674,
#  ('?', '--'): 7.866582756450598e-05,
#  ('в', 'сердцах'): 7.555152614082804e-05,
#  ('сердцах', ','): 8.311170212765957e-05,
#  (',', 'поскольку'): 0.0006036217303822937,
#  ('поскольку', 'грубиян'): 8.301510874979246e-05,
#  ('грубиян', 'угрюмо'): 8.311170212765957e-05,
#  ('угрюмо', 'молчал'): 8.3108248493663e-05,
#  ('молчал', ','): 8.31013420866747e-05,
#  (',', 'сказала'): 5.748778384593274e-05,
#  ('сказала', 'жена'): 0.00020758085274214305,
#  ('жена', '.'): 0.00029036004645760743,
#  ('--', 'А'): 0.004171970018384953,
#  ('А', 'ведь'): 8.21422704123542e-05,
#  ('ведь', 'и'): 0.0002483649308717609,
#  ('и', 'в'): 0.0027153416804947955,
#  ('в', 'самом'): 0.0005288606829857963,
#  ('самом', 'деле'): 0.0009132041011165996,
#  ('деле', ','): 0.00024909702329057166,
#  ('--', 'вслух'): 7.071135624381275e-05,
#  ('вслух', 'согласились'): 8.307717869901138e-05,
#  ('согласились', 'вы'): 8.3108248493663e-05,
#  ('вы', 'с'): 0.00016492125010307578,
#  ('с', 'замечанием'): 8.027292795504716e-05,
#  ('замечанием', 'жены'): 8.311170212765957e-05,
#  ('жены', '.'): 0.00012462094462676026,
#  ('--', 'Вам'): 0.00017677839060953188,
#  ('Вам', ','): 0.00012462094462676026,
#  (',', 'водитель'): 8.623167576889911e-05,
#  (',', 'наверно'): 0.0002874389192296637,
#  ('наверно', ','): 0.00041542040545031574,
#  (',', 'следовало'): 5.748778384593274e-05,
#  ('следовало', 'бы'): 0.00012465201313001205,
#  ('бы', 'что-то'): 8.215239268843705e-05,
#  ('что-то', 'сказать'): 0.00016595444550470895,
#  (',', 'если'): 0.0030181086519114686,
#  ('если', 'после'): 0.00012365524916532706,
#  ('после', 'всего'): 0.00016579623642543314,
#  ('всего', 'я'): 8.288094152749576e-05,
#  ('я', 'дал'): 0.00011729746637472631,
#  ('дал', 'вам'): 8.303923603902844e-05,
#  ('вам', 'десять'): 8.285347363188202e-05,
#  ('десять', 'процентов'): 8.294969101240098e-05,
#  ('процентов', 'на'): 8.31013420866747e-05,
#  ('на', 'чай'): 0.0004717351993081217,
#  ('чай', '.'): 8.307717869901138e-05,
#  ('--', 'При'): 0.00017677839060953188,
#  ('При', 'чем'): 0.000249262598147148,
#  ('чем', 'здесь'): 0.00012393621416177807,
#  ('здесь', 'какие-то'): 8.288437629506838e-05,
#  ('какие-то', '.проценты'): 8.308062975117352e-05,
#  ('.проценты', "''"): 8.311170212765957e-05,
#  ("''", '?'): 0.0035330140535447907,
#  ('--', 'ощерился'): 7.071135624381275e-05,
#  ('ощерился', 'кэбби'): 8.311170212765957e-05,
#  ('кэбби', '.'): 0.0006600387772781651,
#  ('--', 'Вы'): 0.0012020930561448169,
#  ('Вы', 'хотели'): 8.29393713195654e-05,
#  ('хотели', 'оставить'): 8.31013420866747e-05,
#  ('оставить', 'мне'): 8.309788931361143e-05,
#  ('мне', 'меньше'): 8.14265939255761e-05,
#  ('меньше', ','): 0.0004150755437489623,
#  ('чем', 'квотер'): 8.262414277451872e-05,
#  ('квотер', '1'): 8.309098462816784e-05,
#  ('1', '.'): 0.0009548719226138581,
#  ('Забирайте', 'свои'): 8.311170212765957e-05,
#  ('свои', 'деньги'): 8.29393713195654e-05,
#  ('деньги', '!'): 0.0004553922583316084,
#  ('Английскую', 'речь'): 8.311170212765957e-05,
#  ('речь', 'он'): 8.308408109006314e-05,
#  ('он', 'коверкал'): 8.164598301763554e-05,
#  ('коверкал', ';'): 8.311170212765957e-05,
#  (';', 'рука'): 8.207485226526592e-05,
#  ('рука', 'еле'): 8.305992773786287e-05,
#  ('еле', 'сдержалась'): 8.307717869901138e-05,
#  ('сдержалась', ','): 8.311170212765957e-05,
#  (',', 'чтобы'): 0.0033055475711411325,
#  ('чтобы', 'не'): 0.0003721314864585487,
#  ('не', 'хлопнуть'): 7.651109410864575e-05,
#  ('хлопнуть', 'дверцей'): 8.311170212765957e-05,
#  ('дверцей', '...'): 8.310479514667997e-05,
#  ('...', 'А'): 0.0012571204085641329,
#  ('А', 'назавтра'): 0.0001232134056185313,
#  ('назавтра', ','): 0.00012465201313001205,
#  ('когда', 'вы'): 0.00016487366555376944,
#  ('вы', 'покидали'): 8.246062505153789e-05,
#  ('покидали', 'Нью-Йорк'): 8.3108248493663e-05,
#  ('Нью-Йорк', ','): 0.00041509277323481796,
#  (',', 'у'): 0.0016958896234550158,
#  ('у', 'отеля'): 0.0004081799257112535,
#  ('отеля', 'произошло'): 8.297033810412777e-05,
#  ('произошло', 'чудо'): 8.304958059961797e-05,
#  ('чудо', '.'): 0.00012465719272001995,
#  ('Не', 'успели'): 0.00012393109431156277,
#  ('успели', 'вы'): 8.31013420866747e-05,
#  ('с', 'женой'): 0.00048163756773028296,
#  ('женой', 'спуститься'): 8.30702774547267e-05,
#  ('спуститься', 'по'): 8.311170212765957e-05,
#  ('по', 'ступенькам'): 8.15594160345812e-05,
#  ('ступенькам', 'подъезда'): 8.311170212765957e-05,
#  ('подъезда', ','): 0.000249076341898792,
#  (',', 'как'): 0.011066398390342052,
#  ('как', 'один'): 8.147303242626691e-05,
#  ('из', 'дремавших'): 8.144648965629581e-05,
#  ('дремавших', 'в'): 8.311170212765957e-05,
#  ('в', 'очереди'): 0.00045330915684496827,
#  ('очереди', 'таксистов'): 0.0001660164356271271,
#  ('таксистов', ','): 0.0007463924365566429,
#  (',', 'заметив'): 0.00011497556769186548,
#  ('заметив', 'пассажиров'): 8.310479514667997e-05,
#  ('пассажиров', ','): 0.00045635579156986394,
#  (',', 'нажал'): 5.748778384593274e-05,
#  ('нажал', 'на'): 0.0002908305288960904,
#  ('на', 'гудок'): 0.00015724506643604056,
#  ('гудок', ';'): 8.310479514667997e-05,
#  (';', 'другой'): 8.207485226526592e-05,
#  ('другой', ','): 0.0003318538183929979,
#  (',', 'похожий'): 8.623167576889911e-05,
#  ('похожий', ','): 8.3108248493663e-05,
#  (',', 'кстати'): 5.748778384593274e-05,
#  ('кстати', ','): 8.3108248493663e-05,
#  ('на', 'вчерашнего'): 7.862253321802028e-05,
#  ('вчерашнего', ','): 0.0001662026841733494,
#  (',', 'бросился'): 5.748778384593274e-05,
#  ('бросился', 'вам'): 8.3108248493663e-05,
#  ('вам', 'навстречу'): 8.285347363188202e-05,
#  ('навстречу', 'и'): 8.309098462816784e-05,
#  ('и', 'буквально'): 7.54261577915221e-05,
#  ('буквально', 'выхватил'): 8.30702774547267e-05,
#  ('выхватил', 'из'): 8.310479514667997e-05,
#  ('из', 'рук'): 0.00020361622414073952,
#  ('рук', 'чемодан'): 8.306337735692334e-05,
#  ('чемодан', ','): 0.00020755500207555002,
#  ('а', 'третий'): 8.141002157365571e-05,
#  ('третий', ','): 0.00012461576804851708,
#  (',', 'юркий'): 5.748778384593274e-05,
#  ('юркий', 'такой'): 8.311170212765957e-05,
#  ('такой', ','): 0.00020730544384095528,
#  (',', 'опередив'): 5.748778384593274e-05,
#  ('опередив', 'швейцара'): 8.311170212765957e-05,
#  (',', 'услужливо'): 5.748778384593274e-05,
#  ('услужливо', 'распахнул'): 8.311170212765957e-05,
#  ('распахнул', 'дверцу'): 0.0002492936679408343,
#  ('дверцу', '...'): 8.303234109685722e-05,
#  ('...', 'Вы'): 0.00011785503830288745,
#  ('Вы', 'с'): 8.29393713195654e-05,
#  ('женой', 'только'): 8.30702774547267e-05,
#  ('только', 'переглянулись'): 8.244702778464837e-05,
#  ('переглянулись', 'и'): 0.00012465201313001205,
#  ('и', 'еле'): 7.54261577915221e-05,
#  ('еле', 'сдержались'): 8.307717869901138e-05,
#  ('сдержались', ','): 8.311170212765957e-05,
#  (',', 'чтоб'): 0.001465938488071285,
#  ('чтоб', 'не'): 0.0002902276213773374,
#  ('не', 'расхохотаться'): 7.651109410864575e-05,
#  ('расхохотаться', '.'): 8.3108248493663e-05,
#  ('Но', 'каково'): 8.203781943475943e-05,
#  ('каково', 'же'): 8.3108248493663e-05,
#  ('же', 'было'): 0.0002041649652919559,
#  ('было', 'ваше'): 8.208495793145906e-05,
#  ('ваше', 'изумление'): 8.310479514667997e-05,
#  ('изумление', ','): 8.311170212765957e-05,
#  ('вы', 'своими'): 8.246062505153789e-05,
#  ('своими', 'глазами'): 0.00020764981934465716,
#  ('глазами', '--'): 8.30357884248111e-05,
#  ('--', 'не'): 0.0030405883184839487,
#  ('не', 'может'): 0.0007268553940321347,
#  ('может', 'же'): 8.281916435463166e-05,
#  ('же', 'такое'): 8.166598611678236e-05,
#  ('такое', 'померещиться'): 8.302889405513119e-05,
#  ('померещиться', '--'): 8.311170212765957e-05,
#  ('--', 'увидели'): 7.071135624381275e-05,
#  ('увидели', ','): 8.3108248493663e-05,
#  ('как', 'таксист'): 8.147303242626691e-05,
#  ('таксист', '('): 8.292905419413692e-05,
#  ('(', 'определенно'): 8.270272505479056e-05,
#  ('определенно', 'тот'): 8.3108248493663e-05,
#  ('тот', 'самый'): 0.00037321169396641095,
#  ('самый', ','): 0.0002489936506619081,
#  (',', 'вчерашний'): 5.748778384593274e-05,
#  ('вчерашний', '!'): 8.310479514667997e-05,
#  (')', ','): 0.0021503597717310394,
#  (',', 'захлопнув'): 5.748778384593274e-05,
#  ('захлопнув', 'багажник'): 8.311170212765957e-05,
#  ('багажник', ','): 0.0004150066401062417,
#  (',', 'подскочил'): 5.748778384593274e-05,
#  ('подскочил', 'к'): 0.00012465201313001205,
#  ('к', 'швейцару'): 0.0002863571282470853,
#  ('швейцару', 'и'): 0.00012448649321548613,
#  ('и', 'сунул'): 0.00011313923668728315,
#  ('сунул', 'ему'): 8.309098462816784e-05,
#  ('ему', 'ассигнацию'): 8.265487457122784e-05,
#  ('ассигнацию', '...'): 8.310479514667997e-05,
#  ('...', 'Да'): 0.0003142801021410332,
#  ('Да', ','): 0.0012839628893306825,
#  (',', 'да'): 0.001006036217303823,
#  ('да', ':'): 0.00016579623642543314,
#  (':', 'он'): 0.0008268042048899563,
#  ('он', 'вместо'): 8.164598301763554e-05,
#  ('вместо', 'вас'): 8.304958059961797e-05,
#  ('вас', 'уплатил'): 8.282259400364419e-05,
#  ('уплатил', 'чаевые'): 8.310479514667997e-05,
#  ('чаевые', '!'): 8.307717869901138e-05,
#  ('--', 'Аэропорт'): 7.071135624381275e-05,
#  ('Аэропорт', 'Кеннеди'): 8.3108248493663e-05,
#  ('Кеннеди', '!'): 8.285690612312537e-05,
#  ('не', 'слишком'): 0.00011476664116296863,
#  ('слишком', 'любезно'): 8.305647840531562e-05,
#  ('любезно', 'бросили'): 8.311170212765957e-05,
#  ('бросили', 'вы'): 8.310479514667997e-05,
#  ('вы', ','): 0.0006596850004123031,
#  ('не', 'забыв'): 7.651109410864575e-05,
#  ('забыв', 'давешних'): 8.3108248493663e-05,
#  ('давешних', 'сцен'): 8.311170212765957e-05,
#  ('сцен', '.'): 8.311170212765957e-05,
#  ('--', 'Слушаюсь'): 0.00010606703436571913,
#  ('Слушаюсь', ','): 0.0001246623727404945,
#  (',', 'сэр'): 0.0006898534061511929,
#  ('сэр', '!'): 0.0002905649412643726,
#  ('--', 'бойко'): 7.071135624381275e-05,
#  ('бойко', 'откликнулся'): 8.310479514667997e-05,
#  ('откликнулся', 'жлоб'): 8.310479514667997e-05,
#  ('жлоб', ','): 8.3108248493663e-05,
#  ('и', 'кэб'): 0.00018856539447880525,
#  ('кэб', 'рванулся'): 8.251846350620951e-05,
#  ('рванулся', 'к'): 8.3108248493663e-05,
#  ('к', 'переключавшемуся'): 8.181632235631008e-05,
#  ('переключавшемуся', 'светофору'): 8.311170212765957e-05,
#  ('светофору', '...'): 8.311170212765957e-05,
#  ('А', 'теперь'): 0.0002053556760308855,
#  ('теперь', ','): 0.0005796381401896245,
#  ('если', 'вас'): 8.243683277688472e-05,
#  ('вас', 'интересует'): 8.282259400364419e-05,
#  ('интересует', ','): 8.31013420866747e-05,
#  (',', 'откуда'): 0.00025869502730669735,
#  ('откуда', ','): 8.306682726253271e-05,
#  ('да', 'еще'): 0.00041449059106358284,
#  ('еще', 'с'): 0.00016438581350429457,
#  ('с', 'такими'): 8.027292795504716e-05,
#  ('такими', 'подробностями'): 8.309098462816784e-05,
#  ('подробностями', 'известно'): 8.311170212765957e-05,
#  ('известно', 'мне'): 8.309098462816784e-05,
#  ('мне', 'о'): 8.14265939255761e-05,
#  ('о', 'том'): 0.0017694016953337173,
#  ('том', ','): 0.0028969912676406074,
#  ('что', 'произошло'): 0.00019958486348395339,
#  ('произошло', 'между'): 8.304958059961797e-05,
#  ('между', 'вами'): 8.299099547699075e-05,
#  ('вами', 'и'): 8.309098462816784e-05,
#  ('и', 'таксистами'): 7.54261577915221e-05,
#  ('таксистами', 'перед'): 8.308062975117352e-05,
#  ('перед', 'входом'): 0.0003316337105666791,
#  ('входом', 'в'): 0.00041540314875586755,
#  ('в', 'отель'): 0.0006421879721970384,
#  ('отель', ','): 0.000539598206873651,
#  ('в', 'машине'): 0.0004910849199153823,
#  ('и', 'даже'): 0.0006034092623321768,
#  ('даже', 'о'): 8.276432857438444e-05,
#  ('о', 'нелепых'): 8.229775327133569e-05,
#  ('нелепых', 'пререканиях'): 8.311170212765957e-05,
#  ('пререканиях', 'по'): 8.311170212765957e-05,
#  ('по', 'поводу'): 0.00028545795612103415,
#  ('поводу', 'двадцати'): 8.306337735692334e-05,
#  ('двадцати', 'центов'): 8.308408109006314e-05,
#  ('центов', ','): 0.00029062525948683884,
#  (',', 'оставленных'): 5.748778384593274e-05,
#  ('оставленных', 'на'): 8.311170212765957e-05,
#  ('чай', ','): 0.00012461576804851708,
#  (',', 'я'): 0.008565679793043977,
#  ('я', 'откроюсь'): 7.819831091648421e-05,
#  ('откроюсь', ':'): 8.3108248493663e-05,
#  (':', 'плешивый'): 7.874325760856726e-05,
#  ('плешивый', 'жлоб'): 8.3108248493663e-05,
#  ('жлоб', 'с'): 8.3108248493663e-05,
#  ('с', 'небритыми'): 8.027292795504716e-05,
#  ('небритыми', 'щеками'): 8.3108248493663e-05,
#  ('щеками', 'и'): 8.3108248493663e-05,
#  ('и', 'мутным'): 7.54261577915221e-05,
#  ('мутным', 'взглядом'): 0.0001246623727404945,
#  ('взглядом', '--'): 0.000124595066035385,
#  ('--', 'это'): 0.001767783906095319,
#  ('это', 'я'): 0.0003278016799836099,
#  ('я', '.'): 0.0032843290584923367,
#  ('2', '.'): 0.0009547926439453692,
#  ('Эх', ','): 0.0001662026841733494,
#  ('как', 'мне'): 0.00040736516213133454,
#  ('мне', 'знать'): 0.0002442797817767283,
#  ('знать', ':'): 0.00016609916119923594,
#  (':', 'а'): 0.0003543446592385527,
#  ('а', 'вдруг'): 0.0002035250539341393,
#  ('вдруг', 'читатель'): 8.297722275235447e-05,
#  ('читатель', ','): 0.0005813229248847735,
#  (',', 'едва'): 0.0004886461626904283,
#  ('едва', 'раскрыв'): 8.299099547699075e-05,
#  ('раскрыв', 'мои'): 8.3108248493663e-05,
#  ('мои', 'записки'): 8.292217753638211e-05,
#  ('записки', ','): 8.310479514667997e-05,
#  (',', 'уже'): 0.0008623167576889911,
#  ('уже', 'досадует'): 8.231468905626209e-05,
#  ('досадует', ','): 8.3108248493663e-05,
#  ('уже', 'недоволен'): 8.231468905626209e-05,
#  ('недоволен', ';'): 8.310479514667997e-05,
#  (';', 'это'): 0.00028726198292843073,
#  ('это', 'ведь'): 8.195041999590248e-05,
#  ('ведь', 'не'): 0.0004967298617435218,
#  ('не', 'тот'): 7.651109410864575e-05,
#  ('тот', 'благодарный'): 8.293593199253576e-05,
#  ('благодарный', 'русский'): 8.311170212765957e-05,
#  ('русский', 'книголюб'): 8.307372793354102e-05,
#  ('книголюб', ','): 8.311170212765957e-05,
#  ('который', ','): 0.00033057851239669424,
#  (',', 'обнаружив'): 5.748778384593274e-05,
#  ('обнаружив', 'в'): 8.311170212765957e-05,
#  ('в', 'двадцать'): 0.00011332728921124207,
#  ('двадцать', 'шестой'): 8.297378028542981e-05,
#  ('шестой', 'главе'): 8.309788931361143e-05,
#  ('главе', 'первое'): 8.3108248493663e-05,
#  ('первое', 'живое'): 8.30944368274544e-05,
#  ('живое', 'слово'): 8.311170212765957e-05,
#  ('слово', ','): 0.0004151272364979866,
#  (',', 'будет'): 0.00025869502730669735,
#  ('будет', 'уже'): 8.27848834802765e-05,
#  ('уже', 'до'): 8.231468905626209e-05,
#  ('до', 'победного'): 8.257297386565378e-05,
#  ('победного', 'конца'): 8.311170212765957e-05,
#  ('конца', '.давить'): 8.30702774547267e-05,
#  ('.давить', "''"): 8.311170212765957e-05,
#  ("''", 'двухтомный'): 7.851142341210646e-05,
#  ('двухтомный', 'роман'): 8.311170212765957e-05,
#  ('роман', 'про'): 8.310479514667997e-05,
#  ('про', 'династию'): 8.300132802124833e-05,
#  ('династию', 'животноводов'): 8.311170212765957e-05,
#  ('животноводов', 'и'): 8.311170212765957e-05,
#  (',', 'лишь'): 0.00022995113538373097,
#  ('лишь', 'перевернув'): 8.288781134734137e-05,
#  ('перевернув', 'последнюю'): 8.311170212765957e-05,
#  ('последнюю', ','): 8.308062975117352e-05,
#  (',', 'тысяча'): 5.748778384593274e-05,
#  ('тысяча', 'семьсот'): 8.309788931361143e-05,
#  ('семьсот', 'девяносто'): 8.311170212765957e-05,
#  ('девяносто', 'восьмую'): 8.3108248493663e-05,
#  ('восьмую', 'страницу'): 8.311170212765957e-05,
#  ('страницу', ','): 8.310479514667997e-05,
#  (',', 'скажет'): 8.623167576889911e-05,
#  ('скажет', ':'): 0.0003322259136212625,
#  (':', "''"): 0.0006693176896728218,
#  ("''", 'Вот'): 7.851142341210646e-05,
#  ('Вот', 'ведь'): 0.00012445034431261926,
#  ('ведь', 'какая'): 8.278831029058697e-05,
#  ('какая', 'дрянь'): 8.305302935924588e-05,
#  ('дрянь', '!'): 8.3108248493663e-05,
#  ('``', ','): 0.0009075484354654145,
#  ('но', 'и'): 0.0009010853983207045,
#  ('и', 'после'): 0.0002262784733745663,
#  ('после', 'того'): 0.00041449059106358284,
#  ('того', 'не'): 8.286720530350113e-05,
#  ('не', 'зашвырнет'): 7.651109410864575e-05,
#  ('зашвырнет', 'неудавшуюся'): 8.311170212765957e-05,
#  ('неудавшуюся', ','): 8.311170212765957e-05,
#  (',', 'видимо'): 0.00014371945961483184,
#  ('видимо', ','): 0.0002492936679408343,
#  (',', 'новинку'): 5.748778384593274e-05,
#  ('новинку', ','): 8.3108248493663e-05,
#  ('а', 'даст'): 8.141002157365571e-05,
#  ('даст', 'почитать'): 8.309098462816784e-05,
#  ('почитать', 'сослуживцам'): 8.311170212765957e-05,
#  ('сослуживцам', ','): 0.0001246623727404945,
#  ('чтобы', 'проверить'): 0.00012404382881951622,
#  ('проверить', ':'): 8.310479514667997e-05,
#  (':', 'совпадают'): 7.874325760856726e-05,
#  ('совпадают', 'ли'): 8.311170212765957e-05,
#  ('ли', 'мнения'): 8.259002312520647e-05,
#  ('мнения', '?'): 8.3108248493663e-05,
#  ('Здесь', 'ведь'): 8.304268393954493e-05,
#  ('ведь', 'нету'): 8.278831029058697e-05,
#  ('нету', 'таких'): 8.308753271571601e-05,
#  ('таких', '...'): 8.303923603902844e-05,
#  ('А', 'привередливый'): 8.21422704123542e-05,
#  ('привередливый', 'американец'): 8.311170212765957e-05,
#  ('американец', 'уже'): 8.308753271571601e-05,
#  ('уже', 'точно'): 0.00012347203358439315,
#  ('точно', 'досадует'): 8.308753271571601e-05,
#  ('досадует', ':'): 8.3108248493663e-05,
#  (':', 'что'): 0.00043308791684711995,
#  ('что', ','): 0.001596678907871627,
#  (',', 'мол'): 0.0006036217303822937,
#  ('мол', ','): 0.0009134315964293129,
#  (',', 'этот'): 0.00040241448692152917,
#  ('этот', 'таксист'): 8.271640679928864e-05,
#  ('этот', 'эмигрант'): 8.271640679928864e-05,
#  ('эмигрант', ','): 0.0001246623727404945,
#  (',', 'только'): 0.00040241448692152917,
#  ('только', 'морочит'): 8.244702778464837e-05,
#  ('морочит', 'голову'): 8.311170212765957e-05,
#  ('голову', 'и'): 0.00016605089459919466,
#  ('и', 'ничего'): 0.0001508523155830442,
#  ('ничего', 'толком'): 8.291186468783683e-05,
#  ('толком', 'у'): 8.309788931361143e-05,
#  ('у', 'него'): 0.0011020857994203845,
#  ('него', 'не'): 0.000290143413744508,
#  ('не', 'поймешь'): 7.651109410864575e-05,
#  ('поймешь', ':'): 8.3108248493663e-05,
#  (':', 'почему'): 0.00019685814402141817,
#  ('почему', 'вдруг'): 8.293593199253576e-05,
#  ('вдруг', 'ленивые'): 8.297722275235447e-05,
#  ('ленивые', 'кэбби'): 8.3108248493663e-05,
#  ('кэбби', 'кинулись'): 8.250484715977063e-05,
#  ('кинулись', 'усаживать'): 8.311170212765957e-05,
#  ('усаживать', 'пассажиров'): 8.3108248493663e-05,
#  ('пассажиров', 'в'): 0.0002904082309990043,
#  ('в', 'машину'): 0.0005666364460562103,
#  ('машину', '?'): 0.00016572754391779913,
#  ('Да', 'еще'): 0.0001656726308813784,
#  ('еще', 'заплатили'): 8.219290675214729e-05,
#  ('заплатили', 'швейцару'): 8.3108248493663e-05,
#  ('швейцару', '?'): 0.0001659819909539815,
#  ('Скорее', 'всего'): 8.3108248493663e-05,
#  ('всего', ','): 0.0006216070614562182,
#  (',', 'это'): 0.0009772923253808566,
#  ('это', 'вообще'): 8.195041999590248e-05,
#  ('вообще', 'какое-то'): 8.300132802124833e-05,
#  ('какое-то', 'несусветное'): 8.308753271571601e-05,
#  ('несусветное', 'вранье'): 8.3108248493663e-05,
#  ('вранье', ':'): 8.3108248493663e-05,
#  (':', 'чтоб'): 0.0001181148864128509,
#  ('чтоб', 'таксисты'): 8.292217753638211e-05,
#  ('таксисты', 'давали'): 8.302200083022001e-05,
#  ('давали', 'на'): 8.3108248493663e-05,
#  ('чай', '--'): 0.00012461576804851708,
#  ('это', 'что-то'): 8.195041999590248e-05,
#  ('что-то', 'совсем'): 8.297722275235447e-05,
#  ('совсем', 'уж'): 0.0004971208417912921,
#  ('уж', 'неслыханное'): 8.277117907544593e-05,
#  ('неслыханное', '...'): 8.3108248493663e-05,
#  ('...', 'Но'): 0.0021999607149872326,
#  (',', 'ей'): 0.00017246335153779823,
#  ('ей', 'же'): 8.296689620841284e-05,
#  ('же', 'Богу'): 8.166598611678236e-05,
#  ('Богу', ','): 0.0002492833104823632,
#  (',', 'ни'): 0.0031618281115263006,
#  ('ни', 'слова'): 0.0002869322839809805,
#  ('слова', 'вранья'): 8.298755186721991e-05,
#  ('вранья', 'нет'): 8.311170212765957e-05,
#  ('нет', 'в'): 0.00012422360248447205,
#  ('в', 'бесхитростной'): 7.555152614082804e-05,
#  ('бесхитростной', 'моей'): 8.311170212765957e-05,
#  ('моей', 'книжке'): 8.291186468783683e-05,
#  ('книжке', '!'): 8.311170212765957e-05,
#  ('Вам', 'просто'): 8.308062975117352e-05,
#  ('просто', 'не'): 0.00029042027963324066,
#  ('не', 'приходилось'): 0.0001530221882172915,
#  ('приходилось', 'слышать'): 8.308062975117352e-05,
#  ('слышать', 'о'): 8.310479514667997e-05,
#  ('о', 'долларах'): 8.229775327133569e-05,
#  ('долларах', ','): 8.311170212765957e-05,
#  (',', 'которые'): 0.002328255245760276,
#  ('которые', 'тайком'): 8.281916435463166e-05,
#  ('тайком', 'мы'): 8.311170212765957e-05,
#  ('мы', 'платим'): 0.00012371644191513053,
#  ('платим', 'швейцарам'): 8.3108248493663e-05,
#  ('швейцарам', ':'): 0.00012465719272001995,
#  (':', 'один'): 0.00027560140162998545,
#  ('один', '--'): 0.00028957928267074834,
#  ('--', 'за'): 0.000742469240560034,
#  ('за', 'рейс'): 0.00012206037920091139,
#  ('рейс', 'в'): 0.0002077274615704196,
#  ('в', 'ближний'): 0.00011332728921124207,
#  ('ближний', 'аэропорт'): 0.0001246623727404945,
#  ('аэропорт', '``'): 8.299443937256204e-05,
#  ('``', 'Ла-Гвардия'): 0.00023675176577358638,
#  ('Ла-Гвардия', "''"): 0.0002492833104823632,
#  (',', 'два'): 0.00017246335153779823,
#  ('два', '--'): 0.0002485295335929086,
#  ('за', 'дальний'): 8.137358613394092e-05,
#  ('дальний', '``'): 8.3108248493663e-05,
#  ('``', 'Кеннеди'): 0.002406976285364795,
#  ('Кеннеди', "''"): 0.002858563261247825,
#  ('в', 'то'): 0.0003777576307041402,
#  ('то', 'время'): 8.247082594532185e-05,
#  ('время', ','): 0.0004973268680840482,
#  ('когда', 'я'): 0.0011128972424879436,
#  ('я', 'начинал'): 7.819831091648421e-05,
#  ('начинал', 'шоферить'): 8.310479514667997e-05,
#  ('шоферить', ','): 8.311170212765957e-05,
#  (',', 'приходилось'): 5.748778384593274e-05,
#  ('приходилось', 'иной'): 8.308062975117352e-05,
#  ('иной', 'раз'): 0.0004153686396677051,
#  ('раз', 'давать'): 8.271982794275788e-05,
#  ('давать', 'и'): 8.31013420866747e-05,
#  ('и', 'пятерку'): 7.54261577915221e-05,
#  ('пятерку', '--'): 0.00016616125950234703,
#  ('за', 'Нью-Арк'): 8.137358613394092e-05,
#  ('Нью-Арк', '...'): 8.311170212765957e-05,
#  ('...', 'Конечно'): 0.00011785503830288745,
#  ('Конечно', ','): 0.0003738473041455512,
#  ('не', 'всякий'): 7.651109410864575e-05,
#  ('всякий', 'швейцар'): 8.308408109006314e-05,
#  ('швейцар', 'берету'): 8.282259400364419e-05,
#  ('берету', 'таксистов'): 8.311170212765957e-05,
#  ('таксистов', 'взятки'): 8.29324929507381e-05,
#  ('взятки', ','): 8.3108248493663e-05,
#  ('и', 'я'): 0.0019233670236838136,
#  ('я', 'вовсе'): 0.00015639662183296842,
#  ('вовсе', 'не'): 0.0009132420091324201,
#  ('не', 'ставлю'): 7.651109410864575e-05,
#  ('ставлю', 'перед'): 8.311170212765957e-05,
#  ('перед', 'собой'): 0.00016581685528333954,
#  ('собой', 'такой'): 8.300821781356355e-05,
#  ('такой', 'цели'): 8.292217753638211e-05,
#  ('цели', '--'): 0.00012464683397041715,
#  ('--', 'оклеветать'): 7.071135624381275e-05,
#  ('оклеветать', 'всех'): 8.311170212765957e-05,
#  ('всех', 'подряд'): 0.0001658374792703151,
#  ('подряд', 'швейцаров'): 8.30702774547267e-05,
#  ('швейцаров', '.'): 8.309098462816784e-05,
#  ('Тем', 'паче'): 0.0001246416552411816,
#  ...}

# %%
# оценка вероятности новых ngram по статистике text_ngrams_prob
def get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq):
    if ngram in text_ngrams_prob: return text_ngrams_prob[ngram]
    token_0_freq = text_tokens_freq[ngram[0]] if ngram[0] in text_tokens_freq else 0.
    return 1./(token_0_freq+len(text_tokens_freq))

# %% [markdown]
# выбираем дополнение предложения с наибольшей вероятностью цепочки слов
#
# $$
# P(w_1,\ldots, w_n) = \prod_{k=1}^{n} P(w_k|w_k-1)
# $$

# %%
from operator import mul
from functools import reduce 

# оценка предложения
def get_sentence_prob(
        sentence,
        text_ngrams_prob=text_ngrams_prob,
        text_tokens_freq=text_tokens_freq,
        ngram_len=ngram_len
    ):
    return reduce( mul, [ 
        get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq)
        for ngram in nltk_ngrams(sentence,ngram_len) 
    ] )

# %%
# оценка всех возможных продолжений предложения
def get_next_token_prob(sentence,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq):
    
    sentence_prob = get_sentence_prob( # оценка предложения
            sentence,
            text_ngrams_prob=text_ngrams_prob,
            text_tokens_freq=text_tokens_freq
        )
    
    token_next = { # оценки всех возможных продолжений
        ngram[1] : 
            sentence_prob*
              get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq)
        for ngram in text_ngrams_prob if ngram[0]==sentence[-1] 
    }
    
    return token_next

# %%
from collections import OrderedDict

def get_top_prob_token(tokens_prob,n=3):  # n наиболее вероятных продолжений
    kf = lambda k: tokens_prob[k]
    return OrderedDict([
        (key,tokens_prob[key])
        for key in sorted(tokens_prob, key=kf, reverse=True)[:n]
    ])

# %% [markdown]
# ----

# %%
# генерируем продолжения

for sentence in sample(sentences,30):
    if len(sentence)<10: continue
     # берём начало предложения
    sentence_ = sentence[:-(len(sentence)//4)]
    
    # генерируем возможные продолжения
    
    # считаем верояности продолжений
    next_token_prob = get_next_token_prob(sentence_) 
    
    # выбираем наиболее вероятные
    top_prob_token = get_top_prob_token(next_token_prob)
       
    print( 
        ' '.join(sentence_)
        +  ' ... ' 
        + '{ '
        + ' | '.join(top_prob_token.keys())
        + ' }'
        + '\n'
    )
# Out:
# Денег не дали , но он был оптимистом : `` ... { Кеннеди | . | , }
#
# Наутро я снова попытался выиграть гонку за ранним ... { пассажиром }
#
# В десять часов я отвалил от `` Тафта '' ... { , | . | ? }
#
# И они появляются : пес стал неспокойным , утратил аппетит , сон ... Опухоль растет , вызывая у ... { меня | тебя | него }
#
# Печать , залихватские подписи ... Ага , вот : `` Заместитель начальника ... { республиканского | . | тюрьмы }
#
# Я начинял свои передачи отрывками из его открытых писем , очерков и рассказов , которые шли и шли на Запад неведомыми путями , и все переспрашивал самого ... { себя | , | начала }
#
# Я проглотил блесну ... Мало того , что поездка -- трехдолларовая , в скоплении машин ... { , | . | ! }
#
# Лишь один50 ... Если спросить меня , какое самое яркое впечатление вынес я из тех лет , что проработал в такси , обменявшись двумя-тремя словами почти с каждым из ста ... { тысяч | лет | встреченных }
#
# -- басил стражник с револьвером , бросая один за другим на столик , стоявший между ним и преступным ... { кэбби }
#
# И ощущение это -- не результат психического расстройства ; ... { и | но | он }
#
# Ибо , оправдавшись здесь , я смогу предъявить там -- документ о ... { том | чем | чем-то }
#
# Игнорируя черных , я вспоминал пацанов , которые облили меня водой и швырнули в мой кэб камнем ; вспоминал свою поездку с черным солдатом в Джамайку и элегантную молодую мать семейства , которое я однажды вез после рок-концерта ... { -- }
#
# -- Вы хотели оставить мне меньше , чем квотер ... { , | 1 | . }
#
# -- Ты меня не разбудила , я уже встал ... -- Ты не забыл , ... { что | и | а }
#
# -- Троих , -- немедленно сознался я , а странный этот тип аж хлопнул себя по колену от ... { меня | себя | машины }
#
# Несказанное счастье переполняло меня и изливалось -- в ... { `` | том | такси }
#
# Для водителя такси , у которого в банке лежит тысяча долларов , снять кэб в аренду так же просто , как для безденежного кэбби ... { , | . | ! }
#
# Так в тихий предутренний час в воскресенье я оказался в движущейся машине -- один ... Было 3 июля , мой день рождения -- самый радостный с ... { ним | тобой | какой }
#
# -- Разочарованный рубщик с Привоза приподнялся на своем ложе : -- Товарищ Бублик , убедительно прошу вас ответить на тахой вопрос : -- Почему корова делает б л и ... { , | не | в }
#
# -- распространять клеветнические материалы и которая в любой день могла оказаться за решеткой , -- тоже спадут ... { обвинения }
#
# Вот что такое одна посадка : -- Универмаг `` ... { Кеннеди | . | , }
#
# -- Меня все так любят , -- пожаловалась она , едва мы ... { с | не | , }
