# %% [markdown]
# **Статистическая языковая модель**
#
# Евгений Борисов <esborisov@sevsu.ru>
#
# подбираем наиболее вероятное продолжение цепочки слов

# %%
import gzip
import requests
from bs4 import BeautifulSoup

# %%
url='http://lib.ru/NEWPROZA/LOBAS/taxisty.txt'
text = BeautifulSoup(requests.get(url).text).get_text()
with gzip.open('taxisty.txt.gz','wt') as f: f.write(text)

# with gzip.open('taxisty.txt.gz','rt') as f: text = f.read()

text = text[1030:-7261].strip() # выкидываем заголовок и хвост страницы 
print(f'символов:{len(text)}\n---------------\n'%())
print(text[:343])
# Out:
# символов:637765
# ---------------
#
# Вы прилетели в  Нью-Йорк и  остановились  в  одном  из отелей, глядящих
# окнами на Центральный парк.  Наутро по  приезде вы вышли из  отеля, вдохнули
# полной грудью очищенный зеленью парка воздух  и,  взглянув на часы, --  пора
# было начинать хлопотливый день, --  направились к  первому из  таксомоторов,
# выстроившихся вереницей у подъезда.

# %%
# url='http://az.lib.ru/d/dostoewskij_f_m/text_0080.shtml'
# text = BeautifulSoup(requests.get(url).text).get_text()
# with gzip.open('dostoewskij.txt.gz','wt') as f: f.write(text)

# # with gzip.open('dostoewskij.txt.gz','rt') as f: text = f.read()

# text = text[2876:-664184].strip() # выкидываем заголовок и хвост страницы 
# print(f'символов:{len(text)}\n---------------\n'%())
# print(text[:355])

# %%
from nltk import __version__ as nltk_version
print('nltk version:',nltk_version)
# Out:
# nltk version: 3.8.1

# %%
from tqdm.auto import tqdm
from random import sample

from nltk.tokenize import sent_tokenize as nltk_sentence_split
from nltk.tokenize import word_tokenize as nltk_tokenize_word

sentences = [ 
    nltk_tokenize_word(s) # разбиваем предложения на слова
    for s in tqdm(nltk_sentence_split(text)) # режем текст на отдельные предложения
]

print('предложений: %i\n'%(len(sentences)))
display( sample(sentences,1) )
# Out:
#   0%|          | 0/6685 [00:00<?, ?it/s]
# предложений: 6685
# [['Он', 'не', 'упомянул', 'Англию', '.']]

# %%
sentences = sentences[:128] # ограничиваем датасет для ускорения процеса

# %% [markdown]
# ---

# %%
from itertools import chain
from collections import Counter

text_tokens = list(chain(*sentences)) # собираем все токены (слова) из текста
vocab_size = len(set(text_tokens)) # размер словаря

text_tokens_freq = Counter( text_tokens ) # оценка частоты использования слов

print('всего слов тексте: %i'%(len(text_tokens)))
print('размер словаря: %i'%(vocab_size))
text_tokens_freq.most_common()[:10] # наиболее частые токены
# Out:
# всего слов тексте: 3685
# размер словаря: 1651
# [(',', 449),
#  ('и', 111),
#  ('.', 88),
#  ('в', 74),
#  ('--', 62),
#  ('не', 62),
#  ('на', 39),
#  ('с', 38),
#  (':', 34),
#  ('что', 33)]

# %% [markdown]
# ----

# %%
# from nltk.util import bigrams
from nltk.util import ngrams as nltk_ngrams

# вынимаем все n-gram из текста
ngram_len = 2 # работаем с биграммами
text_ngrams = [ ngram for s in sentences for ngram in nltk_ngrams(s,ngram_len) ]
print('количество n-gram: %i'%(len(set(text_ngrams))))
sample(text_ngrams,5)
# Out:
# количество n-gram: 3135
# [('скорее', 'забыть'),
#  ('рука', 'моя'),
#  ('почем', 'и'),
#  ('к', 'этому'),
#  ('Разве', 'вы')]

# %%
# cчитаем частоту n-gram
text_ngrams_freq = Counter(text_ngrams)
sample( list(text_ngrams_freq.items()), 7)
# Out:
# [(('побойчей', ','), 1),
#  (('до', 'лица'), 1),
#  (('двадцать', 'минут'), 1),
#  (('услужливо', 'распахнул'), 1),
#  (('Лимузин', '--'), 1),
#  (('случиться', 'и'), 1),
#  (('...', 'Не'), 1)]

# %%
text_ngrams_freq.most_common()[:10] # наиболее частые n-ngram
# Out:
# [((',', 'и'), 33),
#  ((',', 'а'), 24),
#  ((',', 'что'), 23),
#  ((',', 'как'), 22),
#  (('и', ','), 10),
#  ((',', 'когда'), 10),
#  (("''", ','), 10),
#  ((',', 'я'), 9),
#  ((',', '--'), 8),
#  ((',', 'но'), 8)]

# %% [markdown]
# ----

# %% [markdown]
# Оценка вероятностей совместного использования слов со сглаживанием Лапласа
#
#
# $$
# P(w_n|w_{n-1}) = \frac{ C(w_{n-1} w_{n}) +1 }{ C(w_{n-1}) + V }
# $$

# %%
text_ngrams_prob = { # оценка совместного использования токенов
    ngram : (text_ngrams_freq[ngram]+1) / ( text_tokens_freq[ ngram[0] ] + vocab_size )
    for ngram in text_ngrams_freq 
}

display( text_ngrams_prob )
# Out:
# {('Вы', 'прилетели'): 0.0012091898428053204,
#  ('прилетели', 'в'): 0.0012106537530266344,
#  ('в', 'Нью-Йорк'): 0.0011594202898550724,
#  ('Нью-Йорк', 'и'): 0.0012084592145015106,
#  ('и', 'остановились'): 0.0011350737797956867,
#  ('остановились', 'в'): 0.0012106537530266344,
#  ('в', 'одном'): 0.0017391304347826088,
#  ('одном', 'из'): 0.0018148820326678765,
#  ('из', 'отелей'): 0.001195457262402869,
#  ('отелей', ','): 0.0012099213551119178,
#  (',', 'глядящих'): 0.0009523809523809524,
#  ('глядящих', 'окнами'): 0.0012106537530266344,
#  ('окнами', 'на'): 0.0012106537530266344,
#  ('на', 'Центральный'): 0.0017751479289940828,
#  ('Центральный', 'парк'): 0.0018148820326678765,
#  ('парк', '.'): 0.0018148820326678765,
#  ('Наутро', 'по'): 0.0012106537530266344,
#  ('по', 'приезде'): 0.001201923076923077,
#  ('приезде', 'вы'): 0.0012106537530266344,
#  ('вы', 'вышли'): 0.0011997600479904018,
#  ('вышли', 'из'): 0.0018148820326678765,
#  ('из', 'отеля'): 0.0017931858936043037,
#  ('отеля', ','): 0.0030175015087507543,
#  (',', 'вдохнули'): 0.0009523809523809524,
#  ('вдохнули', 'полной'): 0.0012106537530266344,
#  ('полной', 'грудью'): 0.0012106537530266344,
#  ('грудью', 'очищенный'): 0.0012106537530266344,
#  ('очищенный', 'зеленью'): 0.0012106537530266344,
#  ('зеленью', 'парка'): 0.0012106537530266344,
#  ('парка', 'воздух'): 0.0012091898428053204,
#  ('воздух', 'и'): 0.0012106537530266344,
#  ('и', ','): 0.006242905788876277,
#  (',', 'взглянув'): 0.0009523809523809524,
#  ('взглянув', 'на'): 0.0012106537530266344,
#  ('на', 'часы'): 0.001183431952662722,
#  ('часы', ','): 0.0012106537530266344,
#  (',', '--'): 0.004285714285714286,
#  ('--', 'пора'): 0.0011675423234092236,
#  ('пора', 'было'): 0.0012106537530266344,
#  ('было', 'начинать'): 0.0012062726176115801,
#  ('начинать', 'хлопотливый'): 0.0012106537530266344,
#  ('хлопотливый', 'день'): 0.0012106537530266344,
#  ('день', ','): 0.0018126888217522659,
#  ('--', 'направились'): 0.0011675423234092236,
#  ('направились', 'к'): 0.0012106537530266344,
#  ('к', 'первому'): 0.0011997600479904018,
#  ('первому', 'из'): 0.0012106537530266344,
#  ('из', 'таксомоторов'): 0.001195457262402869,
#  ('таксомоторов', ','): 0.0012106537530266344,
#  (',', 'выстроившихся'): 0.0009523809523809524,
#  ('выстроившихся', 'вереницей'): 0.0012106537530266344,
#  ('вереницей', 'у'): 0.0012106537530266344,
#  ('у', 'подъезда'): 0.001800720288115246,
#  ('подъезда', '.'): 0.0012091898428053204,
#  ('Несколько', 'странным'): 0.0012106537530266344,
#  ('странным', 'вам'): 0.0012106537530266344,
#  ('вам', 'показалось'): 0.0012070006035003018,
#  ('показалось', ','): 0.0012106537530266344,
#  (',', 'что'): 0.011428571428571429,
#  ('что', 'водители'): 0.0011876484560570072,
#  ('водители', 'двух'): 0.0012099213551119178,
#  ('двух', 'головных'): 0.0012099213551119178,
#  ('головных', 'машин'): 0.0012106537530266344,
#  ('машин', 'таксистской'): 0.0012099213551119178,
#  ('таксистской', 'очереди'): 0.0012106537530266344,
#  ('очереди', 'находились'): 0.0012077294685990338,
#  ('находились', 'не'): 0.0012106537530266344,
#  ('не', 'там'): 0.0011675423234092236,
#  ('там', ','): 0.0030211480362537764,
#  (',', 'где'): 0.0033333333333333335,
#  ('где', 'им'): 0.0012070006035003018,
#  ('им', 'полагалось'): 0.0012091898428053204,
#  ('полагалось', 'бы'): 0.0012106537530266344,
#  ('бы', ':'): 0.0012062726176115801,
#  (':', 'за'): 0.0017804154302670622,
#  ('за', 'баранкой'): 0.001199040767386091,
#  ('баранкой', ','): 0.0012106537530266344,
#  (',', 'а'): 0.011904761904761904,
#  ('а', ','): 0.0011933174224343676,
#  (',', 'подпирая'): 0.0009523809523809524,
#  ('подпирая', 'спинами'): 0.0012106537530266344,
#  ('спинами', 'стену'): 0.0012106537530266344,
#  ('стену', 'отеля'): 0.0012106537530266344,
#  (',', 'о'): 0.0014285714285714286,
#  ('о', 'чем-то'): 0.0012033694344163659,
#  ('чем-то', 'болтали'): 0.0012106537530266344,
#  ('болтали', ','): 0.0012106537530266344,
#  (',', 'на'): 0.002380952380952381,
#  ('на', 'пассажира'): 0.001183431952662722,
#  ('пассажира', ','): 0.0018148820326678765,
#  (',', 'заглядывавшего'): 0.0009523809523809524,
#  ('заглядывавшего', 'в'): 0.0012106537530266344,
#  ('в', 'окна'): 0.0011594202898550724,
#  ('окна', 'кэбов'): 0.0012106537530266344,
#  ('кэбов', ','): 0.0018148820326678765,
#  (',', 'внимания'): 0.0009523809523809524,
#  ('внимания', 'не'): 0.0012099213551119178,
#  ('не', 'обращали'): 0.0011675423234092236,
#  ('обращали', ','): 0.0012106537530266344,
#  (',', 'и'): 0.01619047619047619,
#  ('и', 'выглядело'): 0.0011350737797956867,
#  ('выглядело', 'это'): 0.0012106537530266344,
#  ('это', 'так'): 0.0012012012012012011,
#  ('так', ','): 0.0018072289156626507,
#  (',', 'будто'): 0.0014285714285714286,
#  ('будто', 'они'): 0.0012099213551119178,
#  ('они', 'оба'): 0.0012084592145015106,
#  ('оба', 'вообще'): 0.0012106537530266344,
#  ('вообще', 'никуда'): 0.0012099213551119178,
#  ('никуда', 'не'): 0.0018148820326678765,
#  ('не', 'собирались'): 0.0011675423234092236,
#  ('собирались', 'ехать'): 0.0012099213551119178,
#  ('ехать', '.'): 0.0012099213551119178,
#  ('Выждав', 'минуту'): 0.0012106537530266344,
#  ('минуту', 'и'): 0.0012106537530266344,
#  ('и', 'поняв'): 0.0011350737797956867,
#  ('поняв', ','): 0.0012106537530266344,
#  ('что', 'беседа'): 0.0011876484560570072,
#  ('беседа', 'таксистов'): 0.0012106537530266344,
#  ('таксистов', 'может'): 0.0012062726176115801,
#  ('может', 'длиться'): 0.0012062726176115801,
#  ('длиться', 'бесконечно'): 0.0012106537530266344,
#  ('бесконечно', ','): 0.0012106537530266344,
#  (',', 'вы'): 0.002380952380952381,
#  ('вы', 'решились'): 0.0011997600479904018,
#  ('решились', ','): 0.0012106537530266344,
#  (',', 'наконец'): 0.0009523809523809524,
#  ('наконец', ','): 0.0012106537530266344,
#  (',', 'прервать'): 0.0009523809523809524,
#  ('прервать', 'этот'): 0.0012106537530266344,
#  ('этот', 'милый'): 0.0012084592145015106,
#  ('милый', 'tet-a-tet'): 0.0012106537530266344,
#  ('tet-a-tet', 'и'): 0.0012106537530266344,
#  ('и', 'спросили'): 0.0011350737797956867,
#  ('спросили', ':'): 0.0012106537530266344,
#  (':', '--'): 0.002373887240356083,
#  ('--', 'Ну'): 0.0011675423234092236,
#  ('Ну', ','): 0.0018148820326678765,
#  (',', 'ребята'): 0.0009523809523809524,
#  ('ребята', ','): 0.0012106537530266344,
#  (',', 'кто'): 0.0014285714285714286,
#  ('кто', 'из'): 0.0012091898428053204,
#  ('из', 'вас'): 0.001195457262402869,
#  ('вас', 'отвезет'): 0.0012084592145015106,
#  ('отвезет', 'меня'): 0.0012106537530266344,
#  ('меня', '?'): 0.0012091898428053204,
#  ('--', 'Мой'): 0.0011675423234092236,
#  ('Мой', 'кэб'): 0.0012106537530266344,
#  ('кэб', 'занят'): 0.0012062726176115801,
#  ('занят', ','): 0.0012106537530266344,
#  ('--', 'чуть'): 0.0011675423234092236,
#  ('чуть', 'поморщившись'): 0.0012099213551119178,
#  ('поморщившись', ','): 0.0012106537530266344,
#  (',', 'отвечал'): 0.0009523809523809524,
#  ('отвечал', 'один'): 0.0012099213551119178,
#  ('один', 'из'): 0.0018105009052504525,
#  ('из', 'водителей'): 0.001195457262402869,
#  ('водителей', '.'): 0.0012106537530266344,
#  ('--', 'Разве'): 0.0011675423234092236,
#  ('Разве', 'вы'): 0.0012106537530266344,
#  ('вы', 'не'): 0.001799640071985603,
#  ('не', 'видите'): 0.0011675423234092236,
#  ('видите', ','): 0.0012106537530266344,
#  ('что', 'мы'): 0.0011876484560570072,
#  ('мы', 'разговариваем'): 0.0012055455093429777,
#  ('разговариваем', '?'): 0.0012106537530266344,
#  ('--', 'с'): 0.0011675423234092236,
#  ('с', 'режущим'): 0.0011841326228537595,
#  ('режущим', 'слух'): 0.0012106537530266344,
#  ('слух', 'акцентом'): 0.0012099213551119178,
#  ('акцентом', 'сказал'): 0.0012106537530266344,
#  ('сказал', 'второй'): 0.0012099213551119178,
#  ('второй', 'и'): 0.0012106537530266344,
#  ('и', 'при'): 0.00170261066969353,
#  ('при', 'этом'): 0.0018137847642079807,
#  ('этом', 'покачал'): 0.0012099213551119178,
#  ('покачал', 'головой'): 0.0012106537530266344,
#  ('головой', ','): 0.0018148820326678765,
#  (',', 'сетуя'): 0.0009523809523809524,
#  ('сетуя', 'на'): 0.0012106537530266344,
#  ('на', 'всеобщую'): 0.001183431952662722,
#  ('всеобщую', 'невоспитанность'): 0.0012106537530266344,
#  ('невоспитанность', '.'): 0.0012106537530266344,
#  ('Чтобы', 'избежать'): 0.0012106537530266344,
#  ('избежать', 'препирательств'): 0.0012106537530266344,
#  ('препирательств', ','): 0.0012106537530266344,
#  ('вы', 'шагнули'): 0.0011997600479904018,
#  ('шагнули', 'было'): 0.0012106537530266344,
#  ('было', 'к'): 0.0012062726176115801,
#  ('к', 'третьей'): 0.0011997600479904018,
#  ('третьей', 'машине'): 0.0012106537530266344,
#  ('машине', ','): 0.0018137847642079807,
#  (',', 'но'): 0.004285714285714286,
#  ('но', 'водитель'): 0.0012055455093429777,
#  ('водитель', ','): 0.0018148820326678765,
#  (',', 'находившийся'): 0.0009523809523809524,
#  ('находившийся', 'именно'): 0.0012106537530266344,
#  ('именно', 'там'): 0.0012091898428053204,
#  ('где', 'ему'): 0.0012070006035003018,
#  ('ему', 'и'): 0.0012070006035003018,
#  ('и', 'положено'): 0.0011350737797956867,
#  ('положено', ','): 0.0012106537530266344,
#  (',', 'защелкнул'): 0.0009523809523809524,
#  ('защелкнул', 'автоматический'): 0.0012106537530266344,
#  ('автоматический', 'замок'): 0.0012106537530266344,
#  ('замок', '...'): 0.0012106537530266344,
#  ('...', 'Несуразный'): 0.0011926058437686344,
#  ('Несуразный', 'бойкот'): 0.0012106537530266344,
#  ('бойкот', 'этот'): 0.0012106537530266344,
#  ('этот', 'был'): 0.0012084592145015106,
#  ('был', 'тем'): 0.0012091898428053204,
#  ('тем', 'более'): 0.0012091898428053204,
#  ('более', 'оскорбителен'): 0.0012099213551119178,
#  ('оскорбителен', ','): 0.0012106537530266344,
#  ('что', 'невозможно'): 0.0011876484560570072,
#  ('невозможно', 'было'): 0.0012106537530266344,
#  ('было', 'понять'): 0.0012062726176115801,
#  ('понять', ','): 0.0012106537530266344,
#  (',', 'чем'): 0.002857142857142857,
#  ('чем', ','): 0.0012070006035003018,
#  (',', 'собственно'): 0.0009523809523809524,
#  ('собственно', ','): 0.0012106537530266344,
#  (',', 'он'): 0.002857142857142857,
#  ('он', 'вызван'): 0.0011997600479904018,
#  ('вызван', '...'): 0.0012106537530266344,
#  ('...', 'Остановив'): 0.0011926058437686344,
#  ('Остановив', 'пробегавшее'): 0.0012106537530266344,
#  ('пробегавшее', 'мимо'): 0.0012106537530266344,
#  ('мимо', 'такси'): 0.0018137847642079807,
#  ('такси', ','): 0.0018126888217522659,
#  ('вы', 'постарались'): 0.0011997600479904018,
#  ('постарались', 'как'): 0.0012106537530266344,
#  ('как', 'можно'): 0.0017899761336515514,
#  ('можно', 'скорее'): 0.0012091898428053204,
#  ('скорее', 'забыть'): 0.0012106537530266344,
#  ('забыть', 'о'): 0.0012099213551119178,
#  ('о', 'случившемся'): 0.0012033694344163659,
#  ('случившемся', '.'): 0.0012106537530266344,
#  ('Но', 'несколько'): 0.0012055455093429777,
#  ('несколько', 'часов'): 0.0012106537530266344,
#  ('часов', 'спустя'): 0.0012106537530266344,
#  ('спустя', ','): 0.0012106537530266344,
#  (',', 'перед'): 0.0009523809523809524,
#  ('перед', 'вечером'): 0.0012070006035003018,
#  ('вечером', ','): 0.0012106537530266344,
#  (',', 'когда'): 0.005238095238095238,
#  ('когда', 'переодевшись'): 0.0012026458208057728,
#  ('переодевшись', ','): 0.0012106537530266344,
#  (',', 'об'): 0.0009523809523809524,
#  ('об', 'руку'): 0.0012106537530266344,
#  ('руку', 'с'): 0.0012106537530266344,
#  ('с', 'благоухающей'): 0.0011841326228537595,
#  ('благоухающей', 'женой'): 0.0012106537530266344,
#  ('женой', 'вы'): 0.0012091898428053204,
#  ('вы', 'снова'): 0.0011997600479904018,
#  ('снова', 'вышли'): 0.0012106537530266344,
#  (',', 'безобразная'): 0.0009523809523809524,
#  ('безобразная', 'сцена'): 0.0012106537530266344,
#  ('сцена', 'повторилась'): 0.0012106537530266344,
#  ('повторилась', '.'): 0.0012106537530266344,
#  ('Было', 'время'): 0.0012106537530266344,
#  ('время', '``'): 0.0012084592145015106,
#  ('``', 'пик'): 0.0011968880909634949,
#  ('пик', "''"): 0.0012106537530266344,
#  ("''", ','): 0.0065632458233890216,
#  (',', 'в'): 0.0033333333333333335,
#  ('в', 'потоке'): 0.0011594202898550724,
#  ('потоке', 'машин'): 0.0012106537530266344,
#  ('машин', 'свободное'): 0.0012099213551119178,
#  ('свободное', 'такси'): 0.0012106537530266344,
#  ('такси', 'все'): 0.0012084592145015106,
#  ('все', 'никак'): 0.0012048192771084338,
#  ('никак', 'не'): 0.0018148820326678765,
#  ('не', 'попадалось'): 0.0011675423234092236,
#  ('попадалось', ','): 0.0012106537530266344,
#  ('а', 'у'): 0.0011933174224343676,
#  ('подъезда', 'стоял'): 0.0012091898428053204,
#  ('стоял', 'лишь'): 0.0012099213551119178,
#  ('лишь', 'один-единственный'): 0.0012070006035003018,
#  ('один-единственный', 'желтый'): 0.0012106537530266344,
#  ('желтый', 'кэб'): 0.0012106537530266344,
#  ('кэб', '.'): 0.0012062726176115801,
#  ('Неопрятный', 'субъект'): 0.0012106537530266344,
#  ('субъект', 'с'): 0.0012106537530266344,
#  ('с', 'помутневшим'): 0.0011841326228537595,
#  ('помутневшим', 'то'): 0.0012106537530266344,
#  ('то', 'ли'): 0.0018094089264173703,
#  ('ли', 'от'): 0.0018083182640144665,
#  ('от', 'пива'): 0.0012062726176115801,
#  ('пива', ','): 0.0012106537530266344,
#  (',', 'то'): 0.0019047619047619048,
#  ('от', 'безделья'): 0.0012062726176115801,
#  ('безделья', 'взглядом'): 0.0012106537530266344,
#  ('взглядом', 'сидел'): 0.0012099213551119178,
#  ('сидел', 'на'): 0.0012106537530266344,
#  ('на', 'капоте'): 0.001183431952662722,
#  ('капоте', 'и'): 0.0012106537530266344,
#  ('и', 'болтал'): 0.0011350737797956867,
#  ('болтал', 'ногами'): 0.0012106537530266344,
#  ('ногами', '.'): 0.0012106537530266344,
#  ('--', 'Дружище'): 0.0011675423234092236,
#  ('Дружище', ','): 0.0012106537530266344,
#  (',', 'сделайте'): 0.0009523809523809524,
#  ('сделайте', 'одолжение'): 0.0012106537530266344,
#  ('одолжение', ','): 0.0012106537530266344,
#  ('--', 'едва'): 0.0011675423234092236,
#  ('едва', 'ли'): 0.0012099213551119178,
#  ('ли', 'не'): 0.0024110910186859553,
#  ('не', 'заискивая'): 0.0011675423234092236,
#  ('заискивая', ','): 0.0012106537530266344,
#  (',', 'обратились'): 0.0009523809523809524,
#  ('обратились', 'вы'): 0.0012106537530266344,
#  ('вы', 'к'): 0.0011997600479904018,
#  ('к', 'нему'): 0.0011997600479904018,
#  ('нему', ':'): 0.0012106537530266344,
#  ('--', 'отвезите'): 0.0011675423234092236,
#  ('отвезите', 'нас'): 0.0012106537530266344,
#  ('нас', 'в'): 0.0012099213551119178,
#  ('в', 'ресторан'): 0.0011594202898550724,
#  ('ресторан', '.'): 0.0012106537530266344,
#  ('Это', 'совсем'): 0.0012099213551119178,
#  ('совсем', 'недалеко'): 0.0012055455093429777,
#  ('недалеко', ','): 0.0012106537530266344,
#  ('а', 'мы'): 0.0011933174224343676,
#  ('мы', 'будем'): 0.0012055455093429777,
#  ('будем', 'вам'): 0.0012106537530266344,
#  ('вам', 'очень'): 0.0012070006035003018,
#  ('очень', 'признательны'): 0.0012099213551119178,
#  ('признательны', '.'): 0.0012106537530266344,
#  ('Туповатый', 'таксист'): 0.0012106537530266344,
#  ('таксист', ','): 0.002416918429003021,
#  (',', 'однако'): 0.0014285714285714286,
#  ('однако', ','): 0.0018148820326678765,
#  (',', 'не'): 0.0033333333333333335,
#  ('не', 'понял'): 0.0011675423234092236,
#  ('понял', 'намека'): 0.0012106537530266344,
#  ('намека', '.'): 0.0012106537530266344,
#  ('Он', 'с'): 0.0012106537530266344,
#  ('с', 'натугой'): 0.0011841326228537595,
#  ('натугой', 'подавил'): 0.0012106537530266344,
#  ('подавил', 'зевок'): 0.0012106537530266344,
#  ('зевок', 'и'): 0.0012106537530266344,
#  (',', 'проморгавшись'): 0.0009523809523809524,
#  ('проморгавшись', ','): 0.0012106537530266344,
#  (',', 'сказал'): 0.0009523809523809524,
#  ('сказал', ':'): 0.0012099213551119178,
#  ('--', 'Я'): 0.0011675423234092236,
#  ('Я', 'никуда'): 0.0012099213551119178,
#  ('не', 'поеду'): 0.0011675423234092236,
#  ('поеду', '.'): 0.0012106537530266344,
#  ('Я', '--'): 0.0012099213551119178,
#  ('--', 'отдыхаю'): 0.0011675423234092236,
#  ('отдыхаю', '.'): 0.0012106537530266344,
#  ('Швейцар', 'отвернулся'): 0.0012106537530266344,
#  ('отвернулся', ';'): 0.0012106537530266344,
#  (';', 'ему'): 0.0012012012012012011,
#  ('ему', ','): 0.0012070006035003018,
#  (',', 'наверное'): 0.0009523809523809524,
#  ('наверное', ','): 0.0012106537530266344,
#  (',', 'было'): 0.0009523809523809524,
#  ('было', 'стыдно'): 0.0012062726176115801,
#  ('стыдно', 'наблюдать'): 0.0012106537530266344,
#  ('наблюдать', 'эдакое'): 0.0012106537530266344,
#  ('эдакое', 'измывательство'): 0.0012106537530266344,
#  ('измывательство', 'над'): 0.0012106537530266344,
#  ('над', 'гостями'): 0.0012099213551119178,
#  ('гостями', 'престижного'): 0.0012106537530266344,
#  ('престижного', 'отеля-'): 0.0012106537530266344,
#  ('отеля-', 'Пришлось'): 0.0012106537530266344,
#  ('Пришлось', 'повысить'): 0.0012106537530266344,
#  ('повысить', 'голос'): 0.0012106537530266344,
#  ('голос', ','): 0.0012106537530266344,
#  (',', 'окликнуть'): 0.0009523809523809524,
#  ('окликнуть', 'швейцара'): 0.0012106537530266344,
#  ('швейцара', ','): 0.0018126888217522659,
#  ('и', 'тот'): 0.0011350737797956867,
#  ('тот', ','): 0.0012077294685990338,
#  (',', 'надо'): 0.0009523809523809524,
#  ('надо', 'сказать'): 0.0012106537530266344,
#  ('сказать', ','): 0.0018148820326678765,
#  (',', 'живо'): 0.0009523809523809524,
#  ('живо', 'навел'): 0.0012106537530266344,
#  ('навел', 'порядок'): 0.0012106537530266344,
#  ('порядок', ':'): 0.0012106537530266344,
#  (':', 'развязный'): 0.0011869436201780415,
#  ('развязный', 'кэбби'): 0.0012106537530266344,
#  ('кэбби', 'в'): 0.0012070006035003018,
#  ('в', 'два'): 0.0011594202898550724,
#  ('два', 'счета'): 0.0012077294685990338,
#  ('счета', 'оказался'): 0.0012106537530266344,
#  ('оказался', 'за'): 0.0012106537530266344,
#  ('за', 'рулем'): 0.001199040767386091,
#  ('рулем', '.'): 0.0012106537530266344,
#  ('Но', ','): 0.0018083182640144665,
#  (',', 'Бог'): 0.0009523809523809524,
#  ('Бог', 'ты'): 0.0012106537530266344,
#  ('ты', 'мой'): 0.001201923076923077,
#  ('мой', ','): 0.0012070006035003018,
#  (',', 'до'): 0.0014285714285714286,
#  ('до', 'чего'): 0.0018050541516245488,
#  ('чего', 'же'): 0.0012099213551119178,
#  ('же', 'это'): 0.0012026458208057728,
#  ('это', 'неприятно'): 0.0012012012012012011,
#  ('неприятно', ','): 0.0012106537530266344,
#  ('когда', 'везет'): 0.0012026458208057728,
#  ('везет', 'вас'): 0.0012106537530266344,
#  ('вас', 'обозленный'): 0.0012084592145015106,
#  ('обозленный', 'шоферюга'): 0.0012106537530266344,
#  ('шоферюга', ','): 0.0012106537530266344,
#  (',', 'который'): 0.002857142857142857,
#  ('который', 'все'): 0.0012070006035003018,
#  ('все', 'время'): 0.0012048192771084338,
#  ('время', 'бурчит'): 0.0012084592145015106,
#  ('бурчит', 'что-то'): 0.0012106537530266344,
#  ('что-то', 'себе'): 0.0012091898428053204,
#  ('себе', 'под'): 0.0012084592145015106,
#  ('под', 'нос'): 0.0012084592145015106,
#  ('нос', ','): 0.0012106537530266344,
#  (',', 'гримасничает'): 0.0009523809523809524,
#  ('гримасничает', 'и'): 0.0012106537530266344,
#  ('и', 'вам'): 0.0011350737797956867,
#  ('вам', 'назло'): 0.0012070006035003018,
#  ('назло', 'резко'): 0.0012106537530266344,
#  ('резко', 'тормозит'): 0.0012106537530266344,
#  ('тормозит', 'на'): 0.0012106537530266344,
#  ('на', 'перекрестках'): 0.001183431952662722,
#  ('перекрестках', '.'): 0.0012106537530266344,
#  ('Притихнув', 'на'): 0.0012106537530266344,
#  ('на', 'заднем'): 0.001183431952662722,
#  ('заднем', 'сиденье'): 0.0012106537530266344,
#  ('сиденье', ','): 0.0012106537530266344,
#  ('вы', 'молча'): 0.0011997600479904018,
#  ('молча', 'разглядываете'): 0.0012106537530266344,
#  ('разглядываете', 'плешивый'): 0.0012106537530266344,
#  ('плешивый', 'затылок'): 0.0012099213551119178,
#  ('затылок', 'над'): 0.0012106537530266344,
#  ('над', 'несвежим'): 0.0012099213551119178,
#  ('несвежим', 'воротничком'): 0.0012106537530266344,
#  ('воротничком', 'и'): 0.0012106537530266344,
#  ('и', '--'): 0.0011350737797956867,
#  ('--', 'в'): 0.002918855808523059,
#  ('в', 'зеркало'): 0.0011594202898550724,
#  ('зеркало', 'заднего'): 0.0012106537530266344,
#  ('заднего', 'обзора'): 0.0012106537530266344,
#  ('обзора', '--'): 0.0012106537530266344,
#  ('--', 'обрюзгшие'): 0.0011675423234092236,
#  ('обрюзгшие', 'небритые'): 0.0012106537530266344,
#  ('небритые', 'щеки'): 0.0012106537530266344,
#  ('щеки', '.'): 0.0012106537530266344,
#  ('К', 'счастью'): 0.0012091898428053204,
#  ('счастью', ','): 0.0012106537530266344,
#  (',', 'поездка'): 0.0009523809523809524,
#  ('поездка', 'длится'): 0.0012099213551119178,
#  ('длится', 'лишь'): 0.0012106537530266344,
#  ('лишь', 'считанные'): 0.0012070006035003018,
#  ('считанные', 'минуты'): 0.0012106537530266344,
#  ('минуты', ','): 0.0012106537530266344,
#  ('когда', 'кэб'): 0.0012026458208057728,
#  ('кэб', 'останавливается'): 0.0012062726176115801,
#  ('останавливается', ','): 0.0012106537530266344,
#  (',', 'счетчик'): 0.0009523809523809524,
#  ('счетчик', 'показывает'): 0.0012099213551119178,
#  ('показывает', '1.80'): 0.0012106537530266344,
#  ('1.80', '.'): 0.0012106537530266344,
#  ('Инцидент', 'исчерпан'): 0.0012106537530266344,
#  ('исчерпан', ';'): 0.0012106537530266344,
#  (';', 'водителю'): 0.0012012012012012011,
#  ('водителю', 'протянуты'): 0.0012106537530266344,
#  ('протянуты', 'две'): 0.0012106537530266344,
#  ('две', 'долларовые'): 0.0012106537530266344,
#  ('долларовые', 'бумажки'): 0.0012106537530266344,
#  ('бумажки', 'и'): 0.0012106537530266344,
#  ('и', 'сказано'): 0.0011350737797956867,
#  ('сказано', ','): 0.0012106537530266344,
#  ('что', 'сдачу'): 0.0011876484560570072,
#  ('сдачу', 'он'): 0.0012106537530266344,
#  ('он', 'может'): 0.0011997600479904018,
#  ('может', 'оставить'): 0.0012062726176115801,
#  ('оставить', 'себе'): 0.0012091898428053204,
#  ('себе', '.'): 0.0012084592145015106,
#  ('--', 'Зачем'): 0.0011675423234092236,
#  ('Зачем', 'ты'): 0.0012106537530266344,
#  ('ты', 'это'): 0.001201923076923077,
#  ('это', 'делаешь'): 0.0012012012012012011,
#  ('делаешь', '?'): 0.0012106537530266344,
#  ('?', '--'): 0.0011961722488038277,
#  ('в', 'сердцах'): 0.0011594202898550724,
#  ('сердцах', ','): 0.0012106537530266344,
#  (',', 'поскольку'): 0.0009523809523809524,
#  ('поскольку', 'грубиян'): 0.0012106537530266344,
#  ('грубиян', 'угрюмо'): 0.0012106537530266344,
#  ('угрюмо', 'молчал'): 0.0012106537530266344,
#  ('молчал', ','): 0.0012106537530266344,
#  (',', 'сказала'): 0.0009523809523809524,
#  ('сказала', 'жена'): 0.0012106537530266344,
#  ('жена', '.'): 0.0012099213551119178,
#  ('--', 'А'): 0.0011675423234092236,
#  ('А', 'ведь'): 0.0012033694344163659,
#  ('ведь', 'и'): 0.0012062726176115801,
#  ('и', 'в'): 0.00340522133938706,
#  ('в', 'самом'): 0.0011594202898550724,
#  ('самом', 'деле'): 0.0012106537530266344,
#  ('деле', ','): 0.0012106537530266344,
#  ('--', 'вслух'): 0.0011675423234092236,
#  ('вслух', 'согласились'): 0.0012106537530266344,
#  ('согласились', 'вы'): 0.0012106537530266344,
#  ('вы', 'с'): 0.001799640071985603,
#  ('с', 'замечанием'): 0.0011841326228537595,
#  ('замечанием', 'жены'): 0.0012106537530266344,
#  ('жены', '.'): 0.0012106537530266344,
#  ('--', 'Вам'): 0.0011675423234092236,
#  ('Вам', ','): 0.0012099213551119178,
#  (',', 'водитель'): 0.0009523809523809524,
#  (',', 'наверно'): 0.0009523809523809524,
#  ('наверно', ','): 0.0012106537530266344,
#  (',', 'следовало'): 0.0009523809523809524,
#  ('следовало', 'бы'): 0.0012106537530266344,
#  ('бы', 'что-то'): 0.0012062726176115801,
#  ('что-то', 'сказать'): 0.0012091898428053204,
#  (',', 'если'): 0.0038095238095238095,
#  ('если', 'после'): 0.0012033694344163659,
#  ('после', 'всего'): 0.0012091898428053204,
#  ('всего', 'я'): 0.0012070006035003018,
#  ('я', 'дал'): 0.0011926058437686344,
#  ('дал', 'вам'): 0.0012099213551119178,
#  ('вам', 'десять'): 0.0012070006035003018,
#  ('десять', 'процентов'): 0.0012106537530266344,
#  ('процентов', 'на'): 0.0012106537530266344,
#  ('на', 'чай'): 0.002366863905325444,
#  ('чай', '.'): 0.0012091898428053204,
#  ('--', 'При'): 0.0011675423234092236,
#  ('При', 'чем'): 0.0012106537530266344,
#  ('чем', 'здесь'): 0.0012070006035003018,
#  ('здесь', 'какие-то'): 0.0012099213551119178,
#  ('какие-то', '.проценты'): 0.0012099213551119178,
#  ('.проценты', "''"): 0.0012106537530266344,
#  ("''", '?'): 0.0011933174224343676,
#  ('--', 'ощерился'): 0.0011675423234092236,
#  ('ощерился', 'кэбби'): 0.0012106537530266344,
#  ('кэбби', '.'): 0.0012070006035003018,
#  ('--', 'Вы'): 0.0011675423234092236,
#  ('Вы', 'хотели'): 0.0012091898428053204,
#  ('хотели', 'оставить'): 0.0012106537530266344,
#  ('оставить', 'мне'): 0.0012091898428053204,
#  ('мне', 'меньше'): 0.0012048192771084338,
#  ('меньше', ','): 0.0018137847642079807,
#  ('чем', 'квотер'): 0.0012070006035003018,
#  ('квотер', '1'): 0.0012106537530266344,
#  ('1', '.'): 0.0018148820326678765,
#  ('Забирайте', 'свои'): 0.0012106537530266344,
#  ('свои', 'деньги'): 0.0012106537530266344,
#  ('деньги', '!'): 0.0012070006035003018,
#  ('Английскую', 'речь'): 0.0012106537530266344,
#  ('речь', 'он'): 0.0012099213551119178,
#  ('он', 'коверкал'): 0.0011997600479904018,
#  ('коверкал', ';'): 0.0012106537530266344,
#  (';', 'рука'): 0.0012012012012012011,
#  ('рука', 'еле'): 0.0012099213551119178,
#  ('еле', 'сдержалась'): 0.0012099213551119178,
#  ('сдержалась', ','): 0.0012106537530266344,
#  (',', 'чтобы'): 0.002857142857142857,
#  ('чтобы', 'не'): 0.0012077294685990338,
#  ('не', 'хлопнуть'): 0.0011675423234092236,
#  ('хлопнуть', 'дверцей'): 0.0012106537530266344,
#  ('дверцей', '...'): 0.0012106537530266344,
#  ('...', 'А'): 0.0035778175313059034,
#  ('А', 'назавтра'): 0.0012033694344163659,
#  ('назавтра', ','): 0.0012106537530266344,
#  ('когда', 'вы'): 0.0018039687312086591,
#  ('вы', 'покидали'): 0.0011997600479904018,
#  ('покидали', 'Нью-Йорк'): 0.0012106537530266344,
#  ('Нью-Йорк', ','): 0.0018126888217522659,
#  (',', 'у'): 0.0014285714285714286,
#  ('у', 'отеля'): 0.0012004801920768306,
#  ('отеля', 'произошло'): 0.0012070006035003018,
#  ('произошло', 'чудо'): 0.0012099213551119178,
#  ('чудо', '.'): 0.0012106537530266344,
#  ('Не', 'успели'): 0.0012091898428053204,
#  ('успели', 'вы'): 0.0012106537530266344,
#  ('с', 'женой'): 0.0017761989342806395,
#  ('женой', 'спуститься'): 0.0012091898428053204,
#  ('спуститься', 'по'): 0.0012106537530266344,
#  ('по', 'ступенькам'): 0.001201923076923077,
#  ('ступенькам', 'подъезда'): 0.0012106537530266344,
#  ('подъезда', ','): 0.0012091898428053204,
#  (',', 'как'): 0.010952380952380953,
#  ('как', 'один'): 0.0011933174224343676,
#  ('из', 'дремавших'): 0.001195457262402869,
#  ('дремавших', 'в'): 0.0012106537530266344,
#  ('в', 'очереди'): 0.0011594202898550724,
#  ('очереди', 'таксистов'): 0.0012077294685990338,
#  ('таксистов', ','): 0.0018094089264173703,
#  (',', 'заметив'): 0.0009523809523809524,
#  ('заметив', 'пассажиров'): 0.0012106537530266344,
#  ('пассажиров', ','): 0.0012099213551119178,
#  (',', 'нажал'): 0.0009523809523809524,
#  ('нажал', 'на'): 0.0012106537530266344,
#  ('на', 'гудок'): 0.001183431952662722,
#  ('гудок', ';'): 0.0012106537530266344,
#  (';', 'другой'): 0.0012012012012012011,
#  ('другой', ','): 0.0012091898428053204,
#  (',', 'похожий'): 0.0009523809523809524,
#  ('похожий', ','): 0.0012106537530266344,
#  (',', 'кстати'): 0.0009523809523809524,
#  ('кстати', ','): 0.0012106537530266344,
#  ('на', 'вчерашнего'): 0.001183431952662722,
#  ('вчерашнего', ','): 0.0012106537530266344,
#  (',', 'бросился'): 0.0009523809523809524,
#  ('бросился', 'вам'): 0.0012106537530266344,
#  ('вам', 'навстречу'): 0.0012070006035003018,
#  ('навстречу', 'и'): 0.0012106537530266344,
#  ('и', 'буквально'): 0.0011350737797956867,
#  ('буквально', 'выхватил'): 0.0012106537530266344,
#  ('выхватил', 'из'): 0.0012106537530266344,
#  ('из', 'рук'): 0.001195457262402869,
#  ('рук', 'чемодан'): 0.0012106537530266344,
#  ('чемодан', ','): 0.0012099213551119178,
#  ('а', 'третий'): 0.0011933174224343676,
#  ('третий', ','): 0.0012106537530266344,
#  (',', 'юркий'): 0.0009523809523809524,
#  ('юркий', 'такой'): 0.0012106537530266344,
#  ('такой', ','): 0.0012091898428053204,
#  (',', 'опередив'): 0.0009523809523809524,
#  ('опередив', 'швейцара'): 0.0012106537530266344,
#  (',', 'услужливо'): 0.0009523809523809524,
#  ('услужливо', 'распахнул'): 0.0012106537530266344,
#  ('распахнул', 'дверцу'): 0.0012106537530266344,
#  ('дверцу', '...'): 0.0012106537530266344,
#  ('...', 'Вы'): 0.0011926058437686344,
#  ('Вы', 'с'): 0.0012091898428053204,
#  ('женой', 'только'): 0.0012091898428053204,
#  ('только', 'переглянулись'): 0.0012070006035003018,
#  ('переглянулись', 'и'): 0.0012106537530266344,
#  ('и', 'еле'): 0.0011350737797956867,
#  ('еле', 'сдержались'): 0.0012099213551119178,
#  ('сдержались', ','): 0.0012106537530266344,
#  (',', 'чтоб'): 0.002380952380952381,
#  ('чтоб', 'не'): 0.0018115942028985507,
#  ('не', 'расхохотаться'): 0.0011675423234092236,
#  ('расхохотаться', '.'): 0.0012106537530266344,
#  ('Но', 'каково'): 0.0012055455093429777,
#  ('каково', 'же'): 0.0012106537530266344,
#  ('же', 'было'): 0.0012026458208057728,
#  ('было', 'ваше'): 0.0012062726176115801,
#  ('ваше', 'изумление'): 0.0012106537530266344,
#  ('изумление', ','): 0.0012106537530266344,
#  ('вы', 'своими'): 0.0011997600479904018,
#  ('своими', 'глазами'): 0.0012106537530266344,
#  ('глазами', '--'): 0.0012106537530266344,
#  ('--', 'не'): 0.002335084646818447,
#  ('не', 'может'): 0.0011675423234092236,
#  ('может', 'же'): 0.0012062726176115801,
#  ('же', 'такое'): 0.0012026458208057728,
#  ('такое', 'померещиться'): 0.0012106537530266344,
#  ('померещиться', '--'): 0.0012106537530266344,
#  ('--', 'увидели'): 0.0011675423234092236,
#  ('увидели', ','): 0.0012106537530266344,
#  ('как', 'таксист'): 0.0011933174224343676,
#  ('таксист', '('): 0.0012084592145015106,
#  ('(', 'определенно'): 0.0012099213551119178,
#  ('определенно', 'тот'): 0.0012106537530266344,
#  ('тот', 'самый'): 0.0012077294685990338,
#  ('самый', ','): 0.0012099213551119178,
#  (',', 'вчерашний'): 0.0009523809523809524,
#  ('вчерашний', '!'): 0.0012106537530266344,
#  (')', ','): 0.0018148820326678765,
#  (',', 'захлопнув'): 0.0009523809523809524,
#  ('захлопнув', 'багажник'): 0.0012106537530266344,
#  ('багажник', ','): 0.0012106537530266344,
#  (',', 'подскочил'): 0.0009523809523809524,
#  ('подскочил', 'к'): 0.0012106537530266344,
#  ('к', 'швейцару'): 0.0011997600479904018,
#  ('швейцару', 'и'): 0.0012077294685990338,
#  ('и', 'сунул'): 0.0011350737797956867,
#  ('сунул', 'ему'): 0.0012099213551119178,
#  ('ему', 'ассигнацию'): 0.0012070006035003018,
#  ('ассигнацию', '...'): 0.0012106537530266344,
#  ('...', 'Да'): 0.0011926058437686344,
#  ('Да', ','): 0.0012091898428053204,
#  (',', 'да'): 0.0019047619047619048,
#  ('да', ':'): 0.0012084592145015106,
#  (':', 'он'): 0.0011869436201780415,
#  ('он', 'вместо'): 0.0011997600479904018,
#  ('вместо', 'вас'): 0.0012106537530266344,
#  ('вас', 'уплатил'): 0.0012084592145015106,
#  ('уплатил', 'чаевые'): 0.0012106537530266344,
#  ('чаевые', '!'): 0.0012106537530266344,
#  ('--', 'Аэропорт'): 0.0011675423234092236,
#  ('Аэропорт', 'Кеннеди'): 0.0012106537530266344,
#  ('Кеннеди', '!'): 0.0012070006035003018,
#  ('не', 'слишком'): 0.0011675423234092236,
#  ('слишком', 'любезно'): 0.0012106537530266344,
#  ('любезно', 'бросили'): 0.0012106537530266344,
#  ('бросили', 'вы'): 0.0012106537530266344,
#  ('вы', ','): 0.0011997600479904018,
#  ('не', 'забыв'): 0.0011675423234092236,
#  ('забыв', 'давешних'): 0.0012106537530266344,
#  ('давешних', 'сцен'): 0.0012106537530266344,
#  ('сцен', '.'): 0.0012106537530266344,
#  ('--', 'Слушаюсь'): 0.0011675423234092236,
#  ('Слушаюсь', ','): 0.0012106537530266344,
#  (',', 'сэр'): 0.0009523809523809524,
#  ('сэр', '!'): 0.0012106537530266344,
#  ('--', 'бойко'): 0.0011675423234092236,
#  ('бойко', 'откликнулся'): 0.0012106537530266344,
#  ('откликнулся', 'жлоб'): 0.0012106537530266344,
#  ('жлоб', ','): 0.0012099213551119178,
#  ('и', 'кэб'): 0.0011350737797956867,
#  ('кэб', 'рванулся'): 0.0012062726176115801,
#  ('рванулся', 'к'): 0.0012106537530266344,
#  ('к', 'переключавшемуся'): 0.0011997600479904018,
#  ('переключавшемуся', 'светофору'): 0.0012106537530266344,
#  ('светофору', '...'): 0.0012106537530266344,
#  ('А', 'теперь'): 0.0012033694344163659,
#  ('теперь', ','): 0.0018148820326678765,
#  ('если', 'вас'): 0.0012033694344163659,
#  ('вас', 'интересует'): 0.0012084592145015106,
#  ('интересует', ','): 0.0012099213551119178,
#  (',', 'откуда'): 0.0009523809523809524,
#  ('откуда', ','): 0.0012106537530266344,
#  ('да', 'еще'): 0.0012084592145015106,
#  ('еще', 'с'): 0.0012062726176115801,
#  ('с', 'такими'): 0.0011841326228537595,
#  ('такими', 'подробностями'): 0.0012106537530266344,
#  ('подробностями', 'известно'): 0.0012106537530266344,
#  ('известно', 'мне'): 0.0012106537530266344,
#  ('мне', 'о'): 0.0012048192771084338,
#  ('о', 'том'): 0.0024067388688327317,
#  ('том', ','): 0.0030211480362537764,
#  ('что', 'произошло'): 0.0011876484560570072,
#  ('произошло', 'между'): 0.0012099213551119178,
#  ('между', 'вами'): 0.0012106537530266344,
#  ('вами', 'и'): 0.0012106537530266344,
#  ('и', 'таксистами'): 0.0011350737797956867,
#  ('таксистами', 'перед'): 0.0012099213551119178,
#  ('перед', 'входом'): 0.0012070006035003018,
#  ('входом', 'в'): 0.0012106537530266344,
#  ('в', 'отель'): 0.0011594202898550724,
#  ('отель', ','): 0.0018148820326678765,
#  ('в', 'машине'): 0.0011594202898550724,
#  ('и', 'даже'): 0.0011350737797956867,
#  ('даже', 'о'): 0.0012048192771084338,
#  ('о', 'нелепых'): 0.0012033694344163659,
#  ('нелепых', 'пререканиях'): 0.0012106537530266344,
#  ('пререканиях', 'по'): 0.0012106537530266344,
#  ('по', 'поводу'): 0.001201923076923077,
#  ('поводу', 'двадцати'): 0.0012106537530266344,
#  ('двадцати', 'центов'): 0.0012106537530266344,
#  ('центов', ','): 0.0012106537530266344,
#  (',', 'оставленных'): 0.0009523809523809524,
#  ('оставленных', 'на'): 0.0012106537530266344,
#  ('чай', ','): 0.0012091898428053204,
#  (',', 'я'): 0.004761904761904762,
#  ('я', 'откроюсь'): 0.0011926058437686344,
#  ('откроюсь', ':'): 0.0012106537530266344,
#  (':', 'плешивый'): 0.0011869436201780415,
#  ('плешивый', 'жлоб'): 0.0012099213551119178,
#  ('жлоб', 'с'): 0.0012099213551119178,
#  ('с', 'небритыми'): 0.0011841326228537595,
#  ('небритыми', 'щеками'): 0.0012106537530266344,
#  ('щеками', 'и'): 0.0012106537530266344,
#  ('и', 'мутным'): 0.0011350737797956867,
#  ('мутным', 'взглядом'): 0.0012106537530266344,
#  ('взглядом', '--'): 0.0012099213551119178,
#  ('--', 'это'): 0.002335084646818447,
#  ('это', 'я'): 0.0018018018018018018,
#  ('я', '.'): 0.0011926058437686344,
#  ('2', '.'): 0.0018137847642079807,
#  ('Эх', ','): 0.0012106537530266344,
#  ('как', 'мне'): 0.0011933174224343676,
#  ('мне', 'знать'): 0.0012048192771084338,
#  ('знать', ':'): 0.0012099213551119178,
#  (':', 'а'): 0.0011869436201780415,
#  ('а', 'вдруг'): 0.0011933174224343676,
#  ('вдруг', 'читатель'): 0.0012091898428053204,
#  ('читатель', ','): 0.0036188178528347406,
#  (',', 'едва'): 0.0009523809523809524,
#  ('едва', 'раскрыв'): 0.0012099213551119178,
#  ('раскрыв', 'мои'): 0.0012106537530266344,
#  ('мои', 'записки'): 0.0012106537530266344,
#  ('записки', ','): 0.0012106537530266344,
#  (',', 'уже'): 0.0014285714285714286,
#  ('уже', 'досадует'): 0.0012062726176115801,
#  ('досадует', ','): 0.0012099213551119178,
#  ('уже', 'недоволен'): 0.0012062726176115801,
#  ('недоволен', ';'): 0.0012106537530266344,
#  (';', 'это'): 0.0012012012012012011,
#  ('это', 'ведь'): 0.0012012012012012011,
#  ('ведь', 'не'): 0.0012062726176115801,
#  ('не', 'тот'): 0.0011675423234092236,
#  ('тот', 'благодарный'): 0.0012077294685990338,
#  ('благодарный', 'русский'): 0.0012106537530266344,
#  ('русский', 'книголюб'): 0.0012106537530266344,
#  ('книголюб', ','): 0.0012106537530266344,
#  ('который', ','): 0.0012070006035003018,
#  (',', 'обнаружив'): 0.0009523809523809524,
#  ('обнаружив', 'в'): 0.0012106537530266344,
#  ('в', 'двадцать'): 0.0011594202898550724,
#  ('двадцать', 'шестой'): 0.0012091898428053204,
#  ('шестой', 'главе'): 0.0012106537530266344,
#  ('главе', 'первое'): 0.0012106537530266344,
#  ('первое', 'живое'): 0.0012106537530266344,
#  ('живое', 'слово'): 0.0012106537530266344,
#  ('слово', ','): 0.0012106537530266344,
#  (',', 'будет'): 0.0009523809523809524,
#  ('будет', 'уже'): 0.0012091898428053204,
#  ('уже', 'до'): 0.0012062726176115801,
#  ('до', 'победного'): 0.0012033694344163659,
#  ('победного', 'конца'): 0.0012106537530266344,
#  ('конца', '.давить'): 0.0012099213551119178,
#  ('.давить', "''"): 0.0012106537530266344,
#  ("''", 'двухтомный'): 0.0011933174224343676,
#  ('двухтомный', 'роман'): 0.0012106537530266344,
#  ('роман', 'про'): 0.0012106537530266344,
#  ('про', 'династию'): 0.0012106537530266344,
#  ('династию', 'животноводов'): 0.0012106537530266344,
#  ('животноводов', 'и'): 0.0012106537530266344,
#  (',', 'лишь'): 0.0009523809523809524,
#  ('лишь', 'перевернув'): 0.0012070006035003018,
#  ('перевернув', 'последнюю'): 0.0012106537530266344,
#  ('последнюю', ','): 0.0012106537530266344,
#  (',', 'тысяча'): 0.0009523809523809524,
#  ('тысяча', 'семьсот'): 0.0012106537530266344,
#  ('семьсот', 'девяносто'): 0.0012106537530266344,
#  ('девяносто', 'восьмую'): 0.0012106537530266344,
#  ('восьмую', 'страницу'): 0.0012106537530266344,
#  ('страницу', ','): 0.0012106537530266344,
#  (',', 'скажет'): 0.0009523809523809524,
#  ('скажет', ':'): 0.0012106537530266344,
#  (':', "''"): 0.0011869436201780415,
#  ("''", 'Вот'): 0.0011933174224343676,
#  ('Вот', 'ведь'): 0.0012099213551119178,
#  ('ведь', 'какая'): 0.0012062726176115801,
#  ('какая', 'дрянь'): 0.0012106537530266344,
#  ('дрянь', '!'): 0.0012106537530266344,
#  ('``', ','): 0.0017953321364452424,
#  ('но', 'и'): 0.0012055455093429777,
#  ('и', 'после'): 0.0011350737797956867,
#  ('после', 'того'): 0.0012091898428053204,
#  ('того', 'не'): 0.0012099213551119178,
#  ('не', 'зашвырнет'): 0.0011675423234092236,
#  ('зашвырнет', 'неудавшуюся'): 0.0012106537530266344,
#  ('неудавшуюся', ','): 0.0012106537530266344,
#  (',', 'видимо'): 0.0009523809523809524,
#  ('видимо', ','): 0.0012106537530266344,
#  (',', 'новинку'): 0.0009523809523809524,
#  ('новинку', ','): 0.0012106537530266344,
#  ('а', 'даст'): 0.0011933174224343676,
#  ('даст', 'почитать'): 0.0012106537530266344,
#  ('почитать', 'сослуживцам'): 0.0012106537530266344,
#  ('сослуживцам', ','): 0.0012106537530266344,
#  ('чтобы', 'проверить'): 0.0018115942028985507,
#  ('проверить', ':'): 0.0012099213551119178,
#  (':', 'совпадают'): 0.0011869436201780415,
#  ('совпадают', 'ли'): 0.0012106537530266344,
#  ('ли', 'мнения'): 0.0012055455093429777,
#  ('мнения', '?'): 0.0012106537530266344,
#  ('Здесь', 'ведь'): 0.0012106537530266344,
#  ('ведь', 'нету'): 0.0012062726176115801,
#  ('нету', 'таких'): 0.0012106537530266344,
#  ('таких', '...'): 0.0012084592145015106,
#  ('А', 'привередливый'): 0.0012033694344163659,
#  ('привередливый', 'американец'): 0.0012106537530266344,
#  ('американец', 'уже'): 0.0012106537530266344,
#  ('уже', 'точно'): 0.0012062726176115801,
#  ('точно', 'досадует'): 0.0012106537530266344,
#  ('досадует', ':'): 0.0012099213551119178,
#  (':', 'что'): 0.0011869436201780415,
#  ('что', ','): 0.0017814726840855108,
#  (',', 'мол'): 0.0014285714285714286,
#  ('мол', ','): 0.0018148820326678765,
#  (',', 'этот'): 0.0014285714285714286,
#  ('этот', 'таксист'): 0.0012084592145015106,
#  ('этот', 'эмигрант'): 0.0012084592145015106,
#  ('эмигрант', ','): 0.0012106537530266344,
#  (',', 'только'): 0.0009523809523809524,
#  ('только', 'морочит'): 0.0012070006035003018,
#  ('морочит', 'голову'): 0.0012106537530266344,
#  ('голову', 'и'): 0.0012099213551119178,
#  ('и', 'ничего'): 0.0011350737797956867,
#  ('ничего', 'толком'): 0.0012099213551119178,
#  ('толком', 'у'): 0.0012106537530266344,
#  ('у', 'него'): 0.0012004801920768306,
#  ('него', 'не'): 0.0012106537530266344,
#  ('не', 'поймешь'): 0.0011675423234092236,
#  ('поймешь', ':'): 0.0012106537530266344,
#  (':', 'почему'): 0.0011869436201780415,
#  ('почему', 'вдруг'): 0.0012099213551119178,
#  ('вдруг', 'ленивые'): 0.0012091898428053204,
#  ('ленивые', 'кэбби'): 0.0012106537530266344,
#  ('кэбби', 'кинулись'): 0.0012070006035003018,
#  ('кинулись', 'усаживать'): 0.0012106537530266344,
#  ('усаживать', 'пассажиров'): 0.0012106537530266344,
#  ('пассажиров', 'в'): 0.0012099213551119178,
#  ('в', 'машину'): 0.002318840579710145,
#  ('машину', '?'): 0.0012070006035003018,
#  ('Да', 'еще'): 0.0012091898428053204,
#  ('еще', 'заплатили'): 0.0012062726176115801,
#  ('заплатили', 'швейцару'): 0.0012106537530266344,
#  ('швейцару', '?'): 0.0012077294685990338,
#  ('Скорее', 'всего'): 0.0012106537530266344,
#  ('всего', ','): 0.0024140012070006035,
#  (',', 'это'): 0.0009523809523809524,
#  ('это', 'вообще'): 0.0012012012012012011,
#  ('вообще', 'какое-то'): 0.0012099213551119178,
#  ('какое-то', 'несусветное'): 0.0012106537530266344,
#  ('несусветное', 'вранье'): 0.0012106537530266344,
#  ('вранье', ':'): 0.0012106537530266344,
#  (':', 'чтоб'): 0.0011869436201780415,
#  ('чтоб', 'таксисты'): 0.0012077294685990338,
#  ('таксисты', 'давали'): 0.0012099213551119178,
#  ('давали', 'на'): 0.0012106537530266344,
#  ('чай', '--'): 0.0012091898428053204,
#  ('это', 'что-то'): 0.0012012012012012011,
#  ('что-то', 'совсем'): 0.0012091898428053204,
#  ('совсем', 'уж'): 0.0012055455093429777,
#  ('уж', 'неслыханное'): 0.0012091898428053204,
#  ('неслыханное', '...'): 0.0012106537530266344,
#  ('...', 'Но'): 0.0017889087656529517,
#  (',', 'ей'): 0.0009523809523809524,
#  ('ей', 'же'): 0.0012099213551119178,
#  ('же', 'Богу'): 0.0012026458208057728,
#  ('Богу', ','): 0.0018148820326678765,
#  (',', 'ни'): 0.002857142857142857,
#  ('ни', 'слова'): 0.0012033694344163659,
#  ('слова', 'вранья'): 0.0012106537530266344,
#  ('вранья', 'нет'): 0.0012106537530266344,
#  ('нет', 'в'): 0.0012077294685990338,
#  ('в', 'бесхитростной'): 0.0011594202898550724,
#  ('бесхитростной', 'моей'): 0.0012106537530266344,
#  ('моей', 'книжке'): 0.0012106537530266344,
#  ('книжке', '!'): 0.0012106537530266344,
#  ('Вам', 'просто'): 0.0012099213551119178,
#  ('просто', 'не'): 0.0012091898428053204,
#  ('не', 'приходилось'): 0.0011675423234092236,
#  ('приходилось', 'слышать'): 0.0012099213551119178,
#  ('слышать', 'о'): 0.0012106537530266344,
#  ('о', 'долларах'): 0.0012033694344163659,
#  ('долларах', ','): 0.0012106537530266344,
#  (',', 'которые'): 0.0009523809523809524,
#  ('которые', 'тайком'): 0.0012106537530266344,
#  ('тайком', 'мы'): 0.0012106537530266344,
#  ('мы', 'платим'): 0.0018083182640144665,
#  ('платим', 'швейцарам'): 0.0012099213551119178,
#  ('швейцарам', ':'): 0.0012106537530266344,
#  (':', 'один'): 0.0011869436201780415,
#  ('один', '--'): 0.0018105009052504525,
#  ('--', 'за'): 0.002918855808523059,
#  ('за', 'рейс'): 0.001199040767386091,
#  ('рейс', 'в'): 0.0012106537530266344,
#  ('в', 'ближний'): 0.0011594202898550724,
#  ('ближний', 'аэропорт'): 0.0012106537530266344,
#  ('аэропорт', '``'): 0.0012099213551119178,
#  ('``', 'Ла-Гвардия'): 0.0017953321364452424,
#  ('Ла-Гвардия', "''"): 0.0018148820326678765,
#  (',', 'два'): 0.0009523809523809524,
#  ('два', '--'): 0.0012077294685990338,
#  ('за', 'дальний'): 0.001199040767386091,
#  ('дальний', '``'): 0.0012106537530266344,
#  ('``', 'Кеннеди'): 0.0023937761819269898,
#  ('Кеннеди', "''"): 0.0024140012070006035,
#  ('в', 'то'): 0.0011594202898550724,
#  ('то', 'время'): 0.0012062726176115801,
#  ('время', ','): 0.0012084592145015106,
#  ('когда', 'я'): 0.0018039687312086591,
#  ('я', 'начинал'): 0.0011926058437686344,
#  ('начинал', 'шоферить'): 0.0012106537530266344,
#  ('шоферить', ','): 0.0012106537530266344,
#  (',', 'приходилось'): 0.0009523809523809524,
#  ('приходилось', 'иной'): 0.0012099213551119178,
#  ('иной', 'раз'): 0.0012106537530266344,
#  ('раз', 'давать'): 0.0012091898428053204,
#  ('давать', 'и'): 0.0012099213551119178,
#  ('и', 'пятерку'): 0.0011350737797956867,
#  ('пятерку', '--'): 0.0012106537530266344,
#  ('за', 'Нью-Арк'): 0.001199040767386091,
#  ('Нью-Арк', '...'): 0.0012106537530266344,
#  ('...', 'Конечно'): 0.0011926058437686344,
#  ('Конечно', ','): 0.0012106537530266344,
#  ('не', 'всякий'): 0.0011675423234092236,
#  ('всякий', 'швейцар'): 0.0012106537530266344,
#  ('швейцар', 'берету'): 0.0012070006035003018,
#  ('берету', 'таксистов'): 0.0012106537530266344,
#  ('таксистов', 'взятки'): 0.0012062726176115801,
#  ('взятки', ','): 0.0012099213551119178,
#  ('и', 'я'): 0.00170261066969353,
#  ('я', 'вовсе'): 0.0011926058437686344,
#  ('вовсе', 'не'): 0.0012106537530266344,
#  ('не', 'ставлю'): 0.0011675423234092236,
#  ('ставлю', 'перед'): 0.0012106537530266344,
#  ('перед', 'собой'): 0.0012070006035003018,
#  ('собой', 'такой'): 0.0012106537530266344,
#  ('такой', 'цели'): 0.0012091898428053204,
#  ('цели', '--'): 0.0012106537530266344,
#  ('--', 'оклеветать'): 0.0011675423234092236,
#  ('оклеветать', 'всех'): 0.0012106537530266344,
#  ('всех', 'подряд'): 0.0012099213551119178,
#  ('подряд', 'швейцаров'): 0.0012106537530266344,
#  ('швейцаров', '.'): 0.0012099213551119178,
#  ('Тем', 'паче'): 0.0012106537530266344,
#  ...}

# %%
# оценка вероятности новых ngram по статистике text_ngrams_prob
def get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq):
    if ngram in text_ngrams_prob: return text_ngrams_prob[ngram]
    token_0_freq = text_tokens_freq[ngram[0]] if ngram[0] in text_tokens_freq else 0.
    return 1./(token_0_freq+len(text_tokens_freq))

# %% [markdown]
# выбираем дополнение предложения с наибольшей вероятностью цепочки слов
#
# $$
# P(w_1,\ldots, w_n) = \prod_{k=1}^{n} P(w_k|w_k-1)
# $$

# %%
from operator import mul
from functools import reduce 

# оценка предложения
def get_sentence_prob(
        sentence,
        text_ngrams_prob=text_ngrams_prob,
        text_tokens_freq=text_tokens_freq,
        ngram_len=ngram_len
    ):
    return reduce( mul, [ 
        get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq)
        for ngram in nltk_ngrams(sentence,ngram_len) 
    ] )

# %%
# оценка всех возможных продолжений предложения
def get_next_token_prob(sentence,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq):
    
    sentence_prob = get_sentence_prob( # оценка предложения
            sentence,
            text_ngrams_prob=text_ngrams_prob,
            text_tokens_freq=text_tokens_freq
        )
    
    token_next = { # оценки всех возможных продолжений
        ngram[1] : 
            sentence_prob*
              get_ngram_prob(ngram,text_ngrams_prob=text_ngrams_prob,text_tokens_freq=text_tokens_freq)
        for ngram in text_ngrams_prob if ngram[0]==sentence[-1] 
    }
    
    return token_next

# %%
from collections import OrderedDict

def get_top_prob_token(tokens_prob,n=3):  # n наиболее вероятных продолжений
    kf = lambda k: tokens_prob[k]
    return OrderedDict([
        (key,tokens_prob[key])
        for key in sorted(tokens_prob, key=kf, reverse=True)[:n]
    ])

# %% [markdown]
# ----

# %%
# генерируем продолжения

for sentence in sample(sentences,30):
    if len(sentence)<10: continue
     # берём начало предложения
    sentence_ = sentence[:-(len(sentence)//4)]
    
    # генерируем возможные продолжения
    
    # считаем верояности продолжений
    next_token_prob = get_next_token_prob(sentence_) 
    
    # выбираем наиболее вероятные
    top_prob_token = get_top_prob_token(next_token_prob)
       
    print( 
        ' '.join(sentence_)
        +  ' ... ' 
        + '{ '
        + ' | '.join(top_prob_token.keys())
        + ' }'
        + '\n'
    )
# Out:
# Не калеча ее ни каторжными трудами , ни многолетним скопидомством , а с помощью одного безупречно легального способа , который сработает даже при условии , что у тебя нет сбережений ... И если тебя интересует только это , тебе не придется ни читать мою книжку , ни даже листать ее , выискивая нужный совет : открывай сразу главу 20 , и через двадцать минут ты будешь знать все необходимое и лишь слегка подивишься тому , до чего это просто , да , может , в уголке твоего сознания мелькнет мысль о том , как много твоих знакомых , которых ты издавна и искренне привык уважать , проделали в свое время ... { `` | бурчит | , }
#
# Отвернется в закуток , проглотит ломоть жирного одесского штруделя с изюмом , закусит хвостом маринованной селедки и , ... { и | а | что }
#
# Сомнений не было : Ангел давал аэропорты , но , оказывается , денег он ... { не | вызван | может }
#
# Раз уж так вышло , что речь почему-то зашла о швейцарах , давай я познакомлю тебя , читатель , со ... { всеми | мной }
#
# Вот и скажите теперь , что вы сделали бы , очутись вы ... { не | с | вышли }
#
# Со стороны , конечно , вам легко рассуждать : ну , и не имей , дескать , с таксистами никаких .дел '' , если не велит начальство , если деньги ... { , | ! | взял }
#
# И тому , говорят , дал `` Кеннеди '' , ... { и | а | что }
#
# .Нет , нет и еще раз нет '' -- отвечал нам ... { дразнящий | Ангел | неподкупный }
#
# Швейцар отвернулся ; ему , наверное , было стыдно наблюдать эдакое измывательство над гостями престижного отеля- Пришлось повысить голос , окликнуть швейцара , и тот , надо сказать , живо навел порядок ... { : }
#
# Мы подождем с четверть часика , пока под звезды не вывалит очередная компашка дельцов , зашибивших сегодня на бирже и ... { , | в | с }
#
# Но что это я все Ангел да Ангел ... { , | даже | не }
#
# Для наших это было так просто , так естественно , ибо когда и какой еврей в Советском Союзе вселяется ... { в }
#
# ) , захлопнув багажник , подскочил к швейцару и сунул ему ассигнацию ... Да , да : он ... { не | вызван | может }
#
# Не успели вы с женой спуститься по ступенькам подъезда , как один из дремавших в очереди таксистов , заметив пассажиров , нажал на гудок ; другой , похожий , кстати , на вчерашнего , бросился вам навстречу и буквально выхватил из рук чемодан , а третий , юркий такой , опередив швейцара , ... { и | а | что }
#
# -- не слишком любезно бросили вы , не забыв ... { давешних }
#
# В нашем доме , а вернее , в огромном , построенном городскими властями жилом комплексе , образованном шестью корпусами , поставленными на границе с черным районом , живет много ... { ... | твоих | , }
#
# Вы прилетели в Нью-Йорк и остановились в одном из отелей , глядящих окнами ... { на }
#
# `` , и ты увидишь , как от загоготавшей в ответ ватаги отделятся двое , которым кажется , ... { и | а | что }
#
# Любому из моих друзей ты можешь оставить на часок в центре города свой `` Мерседес '' без всякого риска , что машину уволокут на штрафную площадку ; захочешь .понюхать '' или `` пустить по вене '' , поставить на бейсбольную команду или же пожелаешь добавить в свою жизнь капельку нежности -- они всегда позаботятся , чтобы ты получил именно то , к чему нынче предрасположен ... А кроме швейцаров я познакомлю тебя с кинозвездой-собакой и с нищим таксистом , который разбогател в течение считанных дней : я покажу тебе , читатель , тот особый Нью-Йорк , каким его видят водители желтых кэбов , а если тебе любопытно -- научу , как ... { можно | один | таксист }
#
# Они же горло готовы перегрызть за свой несчастный ... { доллар }
#
# Выждав минуту и поняв , что беседа таксистов может длиться бесконечно , вы решились , наконец , прервать этот милый tet-a-tet и спросили : -- Ну , ... { и | а | что }
#
# Но каково же было ваше изумление , когда вы своими глазами -- не может же такое померещиться -- увидели , как таксист ... { , | ( }
#
# Чуть ли не сотню в день суют таксисты ... { давали | швейцару }
#
# -- Вам , водитель , наверно , следовало бы что-то сказать , если после всего я дал вам ... { показалось | очень | назло }
#
# И еще кое-кто из моих земляков , из тех , кто побойчей , посмекалистей , успел сообразить , что , получив от города квартиру ... { , | в | без }
#
# Страница за страницей ты , возможно , и сам не заметишь , как добредешь до конца и тут с удивлением обнаружишь , что тебе почему-то совсем не хочется воспользоваться своим новым знанием : тем самым простым и легальным способом , -- даже для того , ... { и | а | что }
